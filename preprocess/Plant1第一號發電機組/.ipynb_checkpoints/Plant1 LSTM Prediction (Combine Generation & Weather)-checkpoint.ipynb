# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import time
import pickle
import warnings

# %%
os.makedirs(r'預測結果圖\Plant1第一號發電機組', exist_ok=True)

# %%
# 讓圖表能顯示中文字體
plt.rcParams['font.sans-serif'] = ['Microsoft JhengHei']  # 微軟正黑體
plt.rcParams['axes.unicode_minus'] = False  # 正確顯示負號

# %% [markdown]
# <h3 style='color:blue'> definition 函式庫 </h3>

# %%
def classify_day_night(dt):
    '''
    區分白天還是晚上
    '''
    t = dt.time()
    if time(6, 0) <= t <= time(18, 30):
        return 'Daytime' # 白天
    else:
        return 'Night' # 晚上

# %%
def encode_time_features(df):
    """
    將 datetime index 分解為時間欄位，並加入週期性時間變數（sin, cos）。
    傳回處理後的 DataFrame，包含指定欄位順序。
    """
    # 時間欄位分解
    df['HOUR'] = df.index.hour # 小時
    df['MINUTE'] = df.index.minute # 分鐘
    df['MINUTES_PASS'] = df['HOUR'] * 60 + df['MINUTE'] #  把一整天的時間轉換成「當天過了幾分鐘」的數值

    # 加入週期性時間變數（sin/cos）
    # 因為時間具有「週期性」，加入"週期性時間編碼"。
    # 將時間轉換成週期性變數（sin/cos），讓模型可以理解「時間是循環的」，而不是線性的。
    # 這樣模型就可以理解「00:00 跟 23:45 很接近」，而不會誤以為差很遠。
    df['TIME_SIN'] = np.sin(2 * np.pi * df['MINUTES_PASS'] / 1440)
    df['TIME_COS'] = np.cos(2 * np.pi * df['MINUTES_PASS'] / 1440)

    # 指定回傳欄位順序
    df = df[['HOUR', 'MINUTE', 'MINUTES_PASS', 'TIME_SIN', 'TIME_COS',
                       'IRRADIATION', 'AMBIENT_TEMPERATURE', 'MODULE_TEMPERATURE', 
                       'DC_POWER' ]]# 指定欄位順序
    
    return df

# %% [markdown]
# <h2> 第一號發電機組發電量與天氣資訊 </h2>

# %%
gen_1 = pd.read_csv(r'Plant_1_Generation_Data.csv') # 發電資料
sens_1 = pd.read_csv(r'Plant_1_Weather_Sensor_Data.csv') # 氣象感測數據

# %%
# 避免原始資料被修改
df_gen1 = gen_1.copy()
df_sens1 = sens_1.copy()

# %%
# 調整資料格式
df_gen1['DATE_TIME'] = pd.to_datetime(df_gen1['DATE_TIME'],format = '%d-%m-%Y %H:%M')
df_sens1['DATE_TIME'] = pd.to_datetime(df_sens1['DATE_TIME'],format = '%Y-%m-%d %H:%M:%S')

# %%
df_gen1 # 發電資料
# Out:
#                 DATE_TIME  PLANT_ID       SOURCE_KEY  DC_POWER  AC_POWER  \
# 0     2020-05-15 00:00:00   4135001  1BY6WEcLGh8j5v7       0.0       0.0
# 1     2020-05-15 00:00:00   4135001  1IF53ai7Xc0U56Y       0.0       0.0
# 2     2020-05-15 00:00:00   4135001  3PZuoBAID5Wc2HD       0.0       0.0
# 3     2020-05-15 00:00:00   4135001  7JYdWkrLSPkdwr4       0.0       0.0
# 4     2020-05-15 00:00:00   4135001  McdE0feGgRqW7Ca       0.0       0.0
# ...                   ...       ...              ...       ...       ...
# 68773 2020-06-17 23:45:00   4135001  uHbuxQJl8lW7ozc       0.0       0.0
# 68774 2020-06-17 23:45:00   4135001  wCURE6d3bPkepu2       0.0       0.0
# 68775 2020-06-17 23:45:00   4135001  z9Y9gH1T5YWrNuG       0.0       0.0
# 68776 2020-06-17 23:45:00   4135001  zBIq5rxdHJRwDNY       0.0       0.0
# 68777 2020-06-17 23:45:00   4135001  zVJPv84UY57bAof       0.0       0.0
#
#        DAILY_YIELD  TOTAL_YIELD
# 0            0.000    6259559.0
# 1            0.000    6183645.0
# 2            0.000    6987759.0
# 3            0.000    7602960.0
# 4            0.000    7158964.0
# ...            ...          ...
# 68773     5967.000    7287002.0
# 68774     5147.625    7028601.0
# 68775     5819.000    7251204.0
# 68776     5817.000    6583369.0
# 68777     5910.000    7363272.0
#
# [68778 rows x 7 columns]

# %%
df_sens1 # 氣象感測數據
# Out:
#                DATE_TIME  PLANT_ID       SOURCE_KEY  AMBIENT_TEMPERATURE  \
# 0    2020-05-15 00:00:00   4135001  HmiyD2TTLFNqkNe            25.184316
# 1    2020-05-15 00:15:00   4135001  HmiyD2TTLFNqkNe            25.084589
# 2    2020-05-15 00:30:00   4135001  HmiyD2TTLFNqkNe            24.935753
# 3    2020-05-15 00:45:00   4135001  HmiyD2TTLFNqkNe            24.846130
# 4    2020-05-15 01:00:00   4135001  HmiyD2TTLFNqkNe            24.621525
# ...                  ...       ...              ...                  ...
# 3177 2020-06-17 22:45:00   4135001  HmiyD2TTLFNqkNe            22.150570
# 3178 2020-06-17 23:00:00   4135001  HmiyD2TTLFNqkNe            22.129816
# 3179 2020-06-17 23:15:00   4135001  HmiyD2TTLFNqkNe            22.008275
# 3180 2020-06-17 23:30:00   4135001  HmiyD2TTLFNqkNe            21.969495
# 3181 2020-06-17 23:45:00   4135001  HmiyD2TTLFNqkNe            21.909288
#
#       MODULE_TEMPERATURE  IRRADIATION
# 0              22.857507          0.0
# 1              22.761668          0.0
# 2              22.592306          0.0
# 3              22.360852          0.0
# 4              22.165423          0.0
# ...                  ...          ...
# 3177           21.480377          0.0
# 3178           21.389024          0.0
# 3179           20.709211          0.0
# 3180           20.734963          0.0
# 3181           20.427972          0.0
#
# [3182 rows x 6 columns]

# %% [markdown]
# <p style='color:blue'> 合併第一號發電機組發電量與天氣資訊 </p>

# %%
# 移除天氣(Weather)資料中的PLANT_ID與SOURCE_KEY欄位
# 並移除發電(Generation)資料中的PLANT_ID
# 保留所有出現過的 DATE_TIME，缺的欄位用 NaN 補齊
df_plant1 = pd.merge(df_gen1.drop(columns = ['PLANT_ID', 'SOURCE_KEY']), 
                     df_sens1.drop(columns = ['PLANT_ID', 'SOURCE_KEY']), 
                     on='DATE_TIME', 
                     how='outer')
df_plant1
# Out:
#                 DATE_TIME  DC_POWER  AC_POWER  DAILY_YIELD  TOTAL_YIELD  \
# 0     2020-05-15 00:00:00       0.0       0.0        0.000    6259559.0
# 1     2020-05-15 00:00:00       0.0       0.0        0.000    6183645.0
# 2     2020-05-15 00:00:00       0.0       0.0        0.000    6987759.0
# 3     2020-05-15 00:00:00       0.0       0.0        0.000    7602960.0
# 4     2020-05-15 00:00:00       0.0       0.0        0.000    7158964.0
# ...                   ...       ...       ...          ...          ...
# 68798 2020-06-17 23:45:00       0.0       0.0     5967.000    7287002.0
# 68799 2020-06-17 23:45:00       0.0       0.0     5147.625    7028601.0
# 68800 2020-06-17 23:45:00       0.0       0.0     5819.000    7251204.0
# 68801 2020-06-17 23:45:00       0.0       0.0     5817.000    6583369.0
# 68802 2020-06-17 23:45:00       0.0       0.0     5910.000    7363272.0
#
#        AMBIENT_TEMPERATURE  MODULE_TEMPERATURE  IRRADIATION
# 0                25.184316           22.857507          0.0
# 1                25.184316           22.857507          0.0
# 2                25.184316           22.857507          0.0
# 3                25.184316           22.857507          0.0
# 4                25.184316           22.857507          0.0
# ...                    ...                 ...          ...
# 68798            21.909288           20.427972          0.0
# 68799            21.909288           20.427972          0.0
# 68800            21.909288           20.427972          0.0
# 68801            21.909288           20.427972          0.0
# 68802            21.909288           20.427972          0.0
#
# [68803 rows x 8 columns]

# %% [markdown]
# ### 🔌 Generation Data 發電資料
#
# | 欄位名稱     | 代表意義 |
# |--------------|----------|
# | `DATE_TIME`  | 時間戳記，每 15 分鐘記錄一次。 |
# | `PLANT_ID`   | 電廠代號（全表相同）。 |
# | `SOURCE_KEY` | Inverter ID，代表某台設備。 |
# | `DC_POWER`   | 此 15 分鐘內產生的直流電功率（kW）。 |
# | `AC_POWER`   | 此 15 分鐘內 Inverter 轉換的交流電功率（kW）。 |
# | `DAILY_YIELD`| 當日累積發電量（kWh），隨時間增加，當天結束歸零重新計算。 |
# | `TOTAL_YIELD`| 該逆變器從啟用以來累積的總發電量（kWh），不可逆遞增。 |

# %% [markdown]
# ### 🌤️ Weather Sensor Data 氣象感測數據
#
# | 欄位名稱              | 代表意義 |
# |-----------------------|----------|
# | `DATE_TIME`           | 時間戳記，每 15 分鐘記錄一次。 |
# | `PLANT_ID`            | 電廠編號（全表相同）。 |
# | `SOURCE_KEY`          | 感測器 ID（僅一個）。 |
# | `AMBIENT_TEMPERATURE` | 廠區環境溫度。 |
# | `MODULE_TEMPERATURE`  | 太陽能版的面板溫度。 |
# | `IRRADIATION`         | 該時段的太陽輻射量（W/m²），可視為發電潛力的驅動因子。 |

# %%
# drop columns
# 移除 DAILY_YIELD & TOTAL_YIELD
df_plant1.drop(columns=['DAILY_YIELD', 'TOTAL_YIELD'], inplace=True)

# %% [markdown]
# <ol> 若預測目標是 DC_POWER（來自太陽能板），則不建議使用 AC_POWER 預測 DC_POWER。
#     <li> 在實體架構中，太陽能板先產生 DC → 經由逆變器 → 轉為 AC，因此 DC 是原因、AC 是結果。 </li>
#     <li> 若使用 AC 當作特徵預測 DC，其實等同於「預知了結果，才去預測前因」，在真實應用中並不合理。 </li>
#     <li> AC_POWER 和 DC_POWER 高度相關，模型會「學會偷看答案」，但實際部署時沒法提前取得 AC。 </li>
#     <li> 現場若要即時預測未來 DC 發電量，是不會已知該時間點的 AC 值的。 </li>
# </ol>

# %%
# drop columns
# 移除 AC_POWER
df_plant1.drop(columns=['AC_POWER'], inplace=True)

# %%
# 有多少缺失值
df_plant1.isnull().sum()
# Out:
# DATE_TIME               0
# DC_POWER               25
# AMBIENT_TEMPERATURE     4
# MODULE_TEMPERATURE      4
# IRRADIATION             4
# dtype: int64

# %%
# 確保 'DATE_TIME' 欄位是 datetime 格式並排序
df_plant1['DATE_TIME'] = pd.to_datetime(df_plant1['DATE_TIME'])
df_plant1 = df_plant1.sort_values('DATE_TIME')
df_plant1.set_index('DATE_TIME', inplace=True) # 設 'DATE_TIME' 為索引
df_plant1
# Out:
#                      DC_POWER  AMBIENT_TEMPERATURE  MODULE_TEMPERATURE  \
# DATE_TIME
# 2020-05-15 00:00:00       0.0            25.184316           22.857507
# 2020-05-15 00:00:00       0.0            25.184316           22.857507
# 2020-05-15 00:00:00       0.0            25.184316           22.857507
# 2020-05-15 00:00:00       0.0            25.184316           22.857507
# 2020-05-15 00:00:00       0.0            25.184316           22.857507
# ...                       ...                  ...                 ...
# 2020-06-17 23:45:00       0.0            21.909288           20.427972
# 2020-06-17 23:45:00       0.0            21.909288           20.427972
# 2020-06-17 23:45:00       0.0            21.909288           20.427972
# 2020-06-17 23:45:00       0.0            21.909288           20.427972
# 2020-06-17 23:45:00       0.0            21.909288           20.427972
#
#                      IRRADIATION
# DATE_TIME
# 2020-05-15 00:00:00          0.0
# 2020-05-15 00:00:00          0.0
# 2020-05-15 00:00:00          0.0
# 2020-05-15 00:00:00          0.0
# 2020-05-15 00:00:00          0.0
# ...                          ...
# 2020-06-17 23:45:00          0.0
# 2020-06-17 23:45:00          0.0
# 2020-06-17 23:45:00          0.0
# 2020-06-17 23:45:00          0.0
# 2020-06-17 23:45:00          0.0
#
# [68803 rows x 4 columns]

# %% [markdown]
# <h3 style='color:blue'> 檢查資料 </h3>

# %% [markdown]
# <p style='color:red'> 檢查發電資料(Generation Data) </p>

# %%
# 檢查發電資料(Generation Data)
# 每個時間點有幾筆資料、是否完整
expected_per_time = df_gen1['SOURCE_KEY'].nunique() # 每個時間點應有多少筆資料？（即感測器數量） => 22
record_counts = df_gen1.groupby('DATE_TIME').size() # 計算每個時間點實際出現幾筆資料
incomplete_time_points = record_counts[record_counts != expected_per_time] # 找出不符合預期的時間點（感測器資料缺失或異常）

# 每 15 分鐘的資料應該會有 N 筆（N = 感測器數量）
print(f'共有 {len(incomplete_time_points)} 個時間點未滿 {expected_per_time} 筆資料')

incomplete_time_points.columns = ['DATE_TIME', 'RECORD_COUNT']
incomplete_time_points
# Out:
# 共有 101 個時間點未滿 22 筆資料
# DATE_TIME
# 2020-05-15 00:00:00    21
# 2020-05-15 00:15:00    21
# 2020-05-15 00:30:00    21
# 2020-05-15 00:45:00    21
# 2020-05-15 01:15:00    21
#                        ..
# 2020-06-06 18:15:00    10
# 2020-06-06 18:30:00    10
# 2020-06-06 18:45:00    10
# 2020-06-06 19:00:00    10
# 2020-06-06 19:15:00    10
# Length: 101, dtype: int64

# %%
# 以時間為單位，加總所有太陽能板的數值
df_gen1_agg = df_gen1.groupby('DATE_TIME').agg({
    'DC_POWER': 'sum',
    'AC_POWER': 'sum',
    'DAILY_YIELD': 'sum',
    'TOTAL_YIELD': 'sum'
}).reset_index()

df_gen1_agg
# Out:
#                DATE_TIME  DC_POWER  AC_POWER    DAILY_YIELD  TOTAL_YIELD
# 0    2020-05-15 00:00:00       0.0       0.0       0.000000  143581676.0
# 1    2020-05-15 00:15:00       0.0       0.0       0.000000  143581676.0
# 2    2020-05-15 00:30:00       0.0       0.0       0.000000  143581676.0
# 3    2020-05-15 00:45:00       0.0       0.0       0.000000  143581676.0
# 4    2020-05-15 01:00:00       0.0       0.0       0.000000  150761642.0
# ...                  ...       ...       ...            ...          ...
# 3153 2020-06-17 22:45:00       0.0       0.0  129571.000000  156142755.0
# 3154 2020-06-17 23:00:00       0.0       0.0  129571.000000  156142755.0
# 3155 2020-06-17 23:15:00       0.0       0.0  129571.000000  156142755.0
# 3156 2020-06-17 23:30:00       0.0       0.0  129571.000000  156142755.0
# 3157 2020-06-17 23:45:00       0.0       0.0  127962.767857  156142755.0
#
# [3158 rows x 5 columns]

# %%
# 檢查發電資料(Generation Data)
# 檢查 ：時間間隔是否為每 15 分鐘
# 是不是確實每15分鐘記錄一次，中間有沒有缺少漏記錄的。
time_diffs = df_gen1_agg['DATE_TIME'].diff() # 計算每一列資料與前一列資料的時間差，表示兩筆資料之間的時間間隔。
abnormal_time_indices = df_gen1_agg.index[time_diffs != pd.Timedelta(minutes=15)] # 找出時間間隔不是「15 分鐘」的資料所在位置。
abnormal_time_records = df_gen1_agg.loc[abnormal_time_indices]
abnormal_time_records = abnormal_time_records[ abnormal_time_records.index != df_gen1_agg.index[0]] # 排除第一筆
abnormal_time_records
# Out:
#                DATE_TIME       DC_POWER      AC_POWER    DAILY_YIELD  \
# 93   2020-05-16 02:00:00       0.000000      0.000000       0.000000
# 420  2020-05-19 12:30:00  216902.333333  21206.966667   77034.500000
# 520  2020-05-20 17:30:00   40675.000000   3987.000000  192204.000000
# 542  2020-05-21 07:45:00   76297.850000   7494.900000    6938.850000
# 724  2020-05-23 06:45:00   14655.700000   1419.493333     562.166667
# 784  2020-05-23 22:00:00       0.000000      0.000000  186728.000000
# 911  2020-05-25 06:00:00       0.000000      0.000000       0.000000
# 1265 2020-05-29 06:15:00   11155.333333   1080.380000      46.900000
# 3089 2020-06-17 06:45:00    9034.500000    877.250000       0.500000
#
#        TOTAL_YIELD
# 93    1.384314e+08
# 420   1.514011e+08
# 520   1.516661e+08
# 542   1.516747e+08
# 724   1.519953e+08
# 784   1.521814e+08
# 911   6.973863e+07
# 1265  1.530511e+08
# 3089  1.560132e+08

# %% [markdown]
# <p style='color:red'> 檢查天氣資料(Weather Data) </p>

# %%
# 檢查天氣資料(Weather Data)
# 檢查 ：時間間隔是否為每 15 分鐘
# 是不是確實每15分鐘記錄一次，中間有沒有缺少漏記錄的。
time_diffs = df_sens1['DATE_TIME'].diff() # 計算每一列資料與前一列資料的時間差，表示兩筆資料之間的時間間隔。
abnormal_time_indices = df_sens1.index[time_diffs != pd.Timedelta(minutes=15)] # 找出時間間隔不是「15 分鐘」的資料所在位置。
abnormal_time_records = df_sens1.loc[abnormal_time_indices]
abnormal_time_records = abnormal_time_records[ abnormal_time_records.index != df_sens1.index[0]] # 排除第一筆
abnormal_time_records
# Out:
#                DATE_TIME  PLANT_ID       SOURCE_KEY  AMBIENT_TEMPERATURE  \
# 93   2020-05-16 02:00:00   4135001  HmiyD2TTLFNqkNe            21.682160
# 420  2020-05-19 12:30:00   4135001  HmiyD2TTLFNqkNe            29.644664
# 520  2020-05-20 17:30:00   4135001  HmiyD2TTLFNqkNe            29.309510
# 549  2020-05-21 07:45:00   4135001  HmiyD2TTLFNqkNe            23.530554
# 732  2020-05-23 06:45:00   4135001  HmiyD2TTLFNqkNe            22.344630
# 792  2020-05-23 22:00:00   4135001  HmiyD2TTLFNqkNe            25.773600
# 1288 2020-05-29 06:15:00   4135001  HmiyD2TTLFNqkNe            20.838399
# 1799 2020-06-03 14:15:00   4135001  HmiyD2TTLFNqkNe            28.361993
#
#       MODULE_TEMPERATURE  IRRADIATION
# 93             20.072144     0.000000
# 420            49.077840     0.738328
# 520            31.839508     0.136164
# 549            30.403243     0.322396
# 732            22.086662     0.045444
# 792            23.732849     0.000000
# 1288           20.166654     0.040902
# 1799           50.627043     0.716680

# %%
# 取出 DATE_TIME 欄位的唯一值，轉為集合
weather_times = set(df_sens1['DATE_TIME'].unique())
generation_times = set(df_gen1['DATE_TIME'].unique())

# %%
# 找出「發電資料中有，但氣象資料沒有的時間點」
print(f'找出發電有但天氣沒有的時間: { sorted(generation_times - weather_times) }')
# Out:
# 找出發電有但天氣沒有的時間: [Timestamp('2020-06-03 14:00:00')]

# %% [markdown]
# <p style='color:red'> ↑ '2020-06-03 14:00:00' 這個時間點僅有四筆發電資料，且加總後明顯低於前後一筆的資料，因此選擇排除這個時間點（保守、乾淨）。 </p>
# 刪除 2020-06-03 14:00:00 這個時間點的數據
#
# 原因：2020-06-03 14:00:00' 這個時間點僅有四筆發電資料，且加總後明顯低於前後一筆的資料，因此選擇排除這個時間點（保守、乾淨）。

# %%
# 刪除索引為 2020-06-03 14:00:00 的資料列
df_plant1 = df_plant1.drop(pd.to_datetime("2020-06-03 14:00:00"))

# %%
# 找出「氣象資料中有，但發電資料沒有的時間點」
print(f'找出天氣有但發電沒有的時間: { sorted(weather_times - generation_times) }')
# Out:
# 找出天氣有但發電沒有的時間: [Timestamp('2020-05-20 23:00:00'), Timestamp('2020-05-20 23:15:00'), Timestamp('2020-05-20 23:30:00'), Timestamp('2020-05-20 23:45:00'), Timestamp('2020-05-21 00:00:00'), Timestamp('2020-05-21 00:15:00'), Timestamp('2020-05-21 00:30:00'), Timestamp('2020-05-23 05:15:00'), Timestamp('2020-05-25 05:45:00'), Timestamp('2020-05-28 22:30:00'), Timestamp('2020-05-28 22:45:00'), Timestamp('2020-05-28 23:00:00'), Timestamp('2020-05-28 23:15:00'), Timestamp('2020-05-28 23:30:00'), Timestamp('2020-05-28 23:45:00'), Timestamp('2020-05-29 00:00:00'), Timestamp('2020-05-29 00:15:00'), Timestamp('2020-05-29 00:30:00'), Timestamp('2020-05-29 00:45:00'), Timestamp('2020-05-29 01:00:00'), Timestamp('2020-05-29 01:15:00'), Timestamp('2020-05-29 01:30:00'), Timestamp('2020-05-29 01:45:00'), Timestamp('2020-06-17 06:15:00'), Timestamp('2020-06-17 06:30:00')]

# %%
for ts, label in [(ts, classify_day_night(ts)) for ts in sorted(weather_times - generation_times)]:
    print(f"{ts} → {label}")
# Out:
# 2020-05-20 23:00:00 → Night
# 2020-05-20 23:15:00 → Night
# 2020-05-20 23:30:00 → Night
# 2020-05-20 23:45:00 → Night
# 2020-05-21 00:00:00 → Night
# 2020-05-21 00:15:00 → Night
# 2020-05-21 00:30:00 → Night
# 2020-05-23 05:15:00 → Night
# 2020-05-25 05:45:00 → Night
# 2020-05-28 22:30:00 → Night
# 2020-05-28 22:45:00 → Night
# 2020-05-28 23:00:00 → Night
# 2020-05-28 23:15:00 → Night
# 2020-05-28 23:30:00 → Night
# 2020-05-28 23:45:00 → Night
# 2020-05-29 00:00:00 → Night
# 2020-05-29 00:15:00 → Night
# 2020-05-29 00:30:00 → Night
# 2020-05-29 00:45:00 → Night
# 2020-05-29 01:00:00 → Night
# 2020-05-29 01:15:00 → Night
# 2020-05-29 01:30:00 → Night
# 2020-05-29 01:45:00 → Night
# 2020-06-17 06:15:00 → Daytime
# 2020-06-17 06:30:00 → Daytime

# %% [markdown]
# <ol style='color:blue'>
#     <li> 發電沒有的時間 => 這段時間通常是夜晚、夜間。 </li>
#     <li> 因此發電量數值若缺，通常補 0（代表夜晚或漏測）。 </li>
#     <li> 例外：06:15:00 及 06:30:00 這兩個時間點為白天。 </li>
# </ol>

# %% [markdown]
# <p style='color:red'> 檢查 df_plant1 合併資料 </p>

# %%
df_plant1.columns
# Out:
# Index(['DC_POWER', 'AMBIENT_TEMPERATURE', 'MODULE_TEMPERATURE', 'IRRADIATION'], dtype='object')

# %%
# 依照 DATE_TIME 時間聚合
df_plant1 = df_plant1.groupby('DATE_TIME').agg({
    'DC_POWER': 'sum',
    #'AC_POWER': 'sum',
    'AMBIENT_TEMPERATURE': 'mean',  # 平均環境溫度
    'MODULE_TEMPERATURE': 'mean',   # 平均模組溫度
    'IRRADIATION': 'mean'           # 平均日照強度
}).reset_index() # Aggregate聚合資料

df_plant1.set_index('DATE_TIME', inplace=True) # 設 'DATE_TIME' 為索引
df_plant1
# Out:
#                      DC_POWER  AMBIENT_TEMPERATURE  MODULE_TEMPERATURE  \
# DATE_TIME
# 2020-05-15 00:00:00       0.0            25.184316           22.857507
# 2020-05-15 00:15:00       0.0            25.084589           22.761668
# 2020-05-15 00:30:00       0.0            24.935753           22.592306
# 2020-05-15 00:45:00       0.0            24.846130           22.360852
# 2020-05-15 01:00:00       0.0            24.621525           22.165423
# ...                       ...                  ...                 ...
# 2020-06-17 22:45:00       0.0            22.150570           21.480377
# 2020-06-17 23:00:00       0.0            22.129816           21.389024
# 2020-06-17 23:15:00       0.0            22.008275           20.709211
# 2020-06-17 23:30:00       0.0            21.969495           20.734963
# 2020-06-17 23:45:00       0.0            21.909288           20.427972
#
#                      IRRADIATION
# DATE_TIME
# 2020-05-15 00:00:00          0.0
# 2020-05-15 00:15:00          0.0
# 2020-05-15 00:30:00          0.0
# 2020-05-15 00:45:00          0.0
# 2020-05-15 01:00:00          0.0
# ...                          ...
# 2020-06-17 22:45:00          0.0
# 2020-06-17 23:00:00          0.0
# 2020-06-17 23:15:00          0.0
# 2020-06-17 23:30:00          0.0
# 2020-06-17 23:45:00          0.0
#
# [3182 rows x 4 columns]

# %%
# Time 分離出時間
df_plant1 = encode_time_features(df_plant1)
df_plant1
# Out:
#                      HOUR  MINUTE  MINUTES_PASS  TIME_SIN  TIME_COS  \
# DATE_TIME
# 2020-05-15 00:00:00     0       0             0  0.000000  1.000000
# 2020-05-15 00:15:00     0      15            15  0.065403  0.997859
# 2020-05-15 00:30:00     0      30            30  0.130526  0.991445
# 2020-05-15 00:45:00     0      45            45  0.195090  0.980785
# 2020-05-15 01:00:00     1       0            60  0.258819  0.965926
# ...                   ...     ...           ...       ...       ...
# 2020-06-17 22:45:00    22      45          1365 -0.321439  0.946930
# 2020-06-17 23:00:00    23       0          1380 -0.258819  0.965926
# 2020-06-17 23:15:00    23      15          1395 -0.195090  0.980785
# 2020-06-17 23:30:00    23      30          1410 -0.130526  0.991445
# 2020-06-17 23:45:00    23      45          1425 -0.065403  0.997859
#
#                      IRRADIATION  AMBIENT_TEMPERATURE  MODULE_TEMPERATURE  \
# DATE_TIME
# 2020-05-15 00:00:00          0.0            25.184316           22.857507
# 2020-05-15 00:15:00          0.0            25.084589           22.761668
# 2020-05-15 00:30:00          0.0            24.935753           22.592306
# 2020-05-15 00:45:00          0.0            24.846130           22.360852
# 2020-05-15 01:00:00          0.0            24.621525           22.165423
# ...                          ...                  ...                 ...
# 2020-06-17 22:45:00          0.0            22.150570           21.480377
# 2020-06-17 23:00:00          0.0            22.129816           21.389024
# 2020-06-17 23:15:00          0.0            22.008275           20.709211
# 2020-06-17 23:30:00          0.0            21.969495           20.734963
# 2020-06-17 23:45:00          0.0            21.909288           20.427972
#
#                      DC_POWER
# DATE_TIME
# 2020-05-15 00:00:00       0.0
# 2020-05-15 00:15:00       0.0
# 2020-05-15 00:30:00       0.0
# 2020-05-15 00:45:00       0.0
# 2020-05-15 01:00:00       0.0
# ...                       ...
# 2020-06-17 22:45:00       0.0
# 2020-06-17 23:00:00       0.0
# 2020-06-17 23:15:00       0.0
# 2020-06-17 23:30:00       0.0
# 2020-06-17 23:45:00       0.0
#
# [3182 rows x 9 columns]

# %%
df_plant1.isnull().sum()
# Out:
# HOUR                   0
# MINUTE                 0
# MINUTES_PASS           0
# TIME_SIN               0
# TIME_COS               0
# IRRADIATION            0
# AMBIENT_TEMPERATURE    0
# MODULE_TEMPERATURE     0
# DC_POWER               0
# dtype: int64

# %%
df_plant1.dtypes
# Out:
# HOUR                     int32
# MINUTE                   int32
# MINUTES_PASS             int32
# TIME_SIN               float64
# TIME_COS               float64
# IRRADIATION            float64
# AMBIENT_TEMPERATURE    float64
# MODULE_TEMPERATURE     float64
# DC_POWER               float64
# dtype: object

# %%
# 檢查 df_plant1 合併資料
# 檢查：時間間隔是否為每 15 分鐘
# 是不是確實每15分鐘記錄一次，中間有沒有缺少漏記錄的。
time_diffs = df_plant1.index.to_series().diff() # 計算每一列資料與前一列資料的時間差，表示兩筆資料之間的時間間隔。
abnormal_time_indices = df_plant1.index[time_diffs != pd.Timedelta(minutes=15)] # 找出時間間隔不是「15 分鐘」的資料所在位置。
abnormal_time_records = df_plant1.loc[abnormal_time_indices]
abnormal_time_records = abnormal_time_records[abnormal_time_records.index != pd.Timestamp('2020-05-15 00:00:00')] # 排除第一筆或指定時間（2020-05-15 00:00:00）
abnormal_time_records
# Out:
#                      HOUR  MINUTE  MINUTES_PASS  TIME_SIN  TIME_COS  \
# DATE_TIME
# 2020-05-16 02:00:00     2       0           120  0.500000  0.866025
# 2020-05-19 12:30:00    12      30           750 -0.130526 -0.991445
# 2020-05-20 17:30:00    17      30          1050 -0.991445 -0.130526
# 2020-05-21 07:45:00     7      45           465  0.896873 -0.442289
# 2020-05-23 06:45:00     6      45           405  0.980785 -0.195090
# 2020-05-23 22:00:00    22       0          1320 -0.500000  0.866025
# 2020-05-29 06:15:00     6      15           375  0.997859 -0.065403
# 2020-06-03 14:15:00    14      15           855 -0.555570 -0.831470
#
#                      IRRADIATION  AMBIENT_TEMPERATURE  MODULE_TEMPERATURE  \
# DATE_TIME
# 2020-05-16 02:00:00     0.000000            21.682160           20.072144
# 2020-05-19 12:30:00     0.738328            29.644664           49.077840
# 2020-05-20 17:30:00     0.136164            29.309510           31.839508
# 2020-05-21 07:45:00     0.322396            23.530554           30.403243
# 2020-05-23 06:45:00     0.045444            22.344630           22.086662
# 2020-05-23 22:00:00     0.000000            25.773600           23.732849
# 2020-05-29 06:15:00     0.040902            20.838399           20.166654
# 2020-06-03 14:15:00     0.716680            28.361993           50.627043
#
#                           DC_POWER
# DATE_TIME
# 2020-05-16 02:00:00       0.000000
# 2020-05-19 12:30:00  216902.333333
# 2020-05-20 17:30:00   40675.000000
# 2020-05-21 07:45:00   76297.850000
# 2020-05-23 06:45:00   14655.700000
# 2020-05-23 22:00:00       0.000000
# 2020-05-29 06:15:00   11155.333333
# 2020-06-03 14:15:00  214739.160718

# %%
# 缺少15分鐘記錄的欄位
full_time_range = pd.date_range(start=df_plant1.index.min(), end=df_plant1.index.max(), freq='15T') # 計算全期間的完整時間序列（每 15 分鐘一筆）
plant1_times = set(df_plant1.index.unique()) # 建立 df_plant1 的唯一時間集合
missing_times = sorted(set(full_time_range) - plant1_times) # # 找出 df_plant1 沒有的時間點

print(f'找出不存在於 df_plant1 的時間點，共 {len(missing_times)} 筆')
missing_times
# Out:
# 找出不存在於 df_plant1 的時間點，共 82 筆
# C:\Users\HoChePing\AppData\Local\Temp\ipykernel_28428\1096867754.py:2: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   full_time_range = pd.date_range(start=df_plant1.index.min(), end=df_plant1.index.max(), freq='15T') # 計算全期間的完整時間序列（每 15 分鐘一筆）
# [Timestamp('2020-05-15 23:15:00'),
#  Timestamp('2020-05-15 23:30:00'),
#  Timestamp('2020-05-15 23:45:00'),
#  Timestamp('2020-05-16 00:00:00'),
#  Timestamp('2020-05-16 00:15:00'),
#  Timestamp('2020-05-16 00:30:00'),
#  Timestamp('2020-05-16 00:45:00'),
#  Timestamp('2020-05-16 01:00:00'),
#  Timestamp('2020-05-16 01:15:00'),
#  Timestamp('2020-05-16 01:30:00'),
#  Timestamp('2020-05-16 01:45:00'),
#  Timestamp('2020-05-19 11:45:00'),
#  Timestamp('2020-05-19 12:00:00'),
#  Timestamp('2020-05-19 12:15:00'),
#  Timestamp('2020-05-20 13:30:00'),
#  Timestamp('2020-05-20 13:45:00'),
#  Timestamp('2020-05-20 14:00:00'),
#  Timestamp('2020-05-20 14:15:00'),
#  Timestamp('2020-05-20 14:30:00'),
#  Timestamp('2020-05-20 14:45:00'),
#  Timestamp('2020-05-20 15:00:00'),
#  Timestamp('2020-05-20 15:15:00'),
#  Timestamp('2020-05-20 15:30:00'),
#  Timestamp('2020-05-20 15:45:00'),
#  Timestamp('2020-05-20 16:00:00'),
#  Timestamp('2020-05-20 16:15:00'),
#  Timestamp('2020-05-20 16:30:00'),
#  Timestamp('2020-05-20 16:45:00'),
#  Timestamp('2020-05-20 17:00:00'),
#  Timestamp('2020-05-20 17:15:00'),
#  Timestamp('2020-05-21 00:45:00'),
#  Timestamp('2020-05-21 01:00:00'),
#  Timestamp('2020-05-21 01:15:00'),
#  Timestamp('2020-05-21 01:30:00'),
#  Timestamp('2020-05-21 01:45:00'),
#  Timestamp('2020-05-21 02:00:00'),
#  Timestamp('2020-05-21 02:15:00'),
#  Timestamp('2020-05-21 02:30:00'),
#  Timestamp('2020-05-21 02:45:00'),
#  Timestamp('2020-05-21 03:00:00'),
#  Timestamp('2020-05-21 03:15:00'),
#  Timestamp('2020-05-21 03:30:00'),
#  Timestamp('2020-05-21 03:45:00'),
#  Timestamp('2020-05-21 04:00:00'),
#  Timestamp('2020-05-21 04:15:00'),
#  Timestamp('2020-05-21 04:30:00'),
#  Timestamp('2020-05-21 04:45:00'),
#  Timestamp('2020-05-21 05:00:00'),
#  Timestamp('2020-05-21 05:15:00'),
#  Timestamp('2020-05-21 05:30:00'),
#  Timestamp('2020-05-21 05:45:00'),
#  Timestamp('2020-05-21 06:00:00'),
#  Timestamp('2020-05-21 06:15:00'),
#  Timestamp('2020-05-21 06:30:00'),
#  Timestamp('2020-05-21 06:45:00'),
#  Timestamp('2020-05-21 07:00:00'),
#  Timestamp('2020-05-21 07:15:00'),
#  Timestamp('2020-05-21 07:30:00'),
#  Timestamp('2020-05-23 05:30:00'),
#  Timestamp('2020-05-23 05:45:00'),
#  Timestamp('2020-05-23 06:00:00'),
#  Timestamp('2020-05-23 06:15:00'),
#  Timestamp('2020-05-23 06:30:00'),
#  Timestamp('2020-05-23 21:45:00'),
#  Timestamp('2020-05-29 02:00:00'),
#  Timestamp('2020-05-29 02:15:00'),
#  Timestamp('2020-05-29 02:30:00'),
#  Timestamp('2020-05-29 02:45:00'),
#  Timestamp('2020-05-29 03:00:00'),
#  Timestamp('2020-05-29 03:15:00'),
#  Timestamp('2020-05-29 03:30:00'),
#  Timestamp('2020-05-29 03:45:00'),
#  Timestamp('2020-05-29 04:00:00'),
#  Timestamp('2020-05-29 04:15:00'),
#  Timestamp('2020-05-29 04:30:00'),
#  Timestamp('2020-05-29 04:45:00'),
#  Timestamp('2020-05-29 05:00:00'),
#  Timestamp('2020-05-29 05:15:00'),
#  Timestamp('2020-05-29 05:30:00'),
#  Timestamp('2020-05-29 05:45:00'),
#  Timestamp('2020-05-29 06:00:00'),
#  Timestamp('2020-06-03 14:00:00')]

# %%
for ts, label in [(ts, classify_day_night(ts)) for ts in missing_times]:
    print(f"{ts} → {label}")
# Out:
# 2020-05-15 23:15:00 → Night
# 2020-05-15 23:30:00 → Night
# 2020-05-15 23:45:00 → Night
# 2020-05-16 00:00:00 → Night
# 2020-05-16 00:15:00 → Night
# 2020-05-16 00:30:00 → Night
# 2020-05-16 00:45:00 → Night
# 2020-05-16 01:00:00 → Night
# 2020-05-16 01:15:00 → Night
# 2020-05-16 01:30:00 → Night
# 2020-05-16 01:45:00 → Night
# 2020-05-19 11:45:00 → Daytime
# 2020-05-19 12:00:00 → Daytime
# 2020-05-19 12:15:00 → Daytime
# 2020-05-20 13:30:00 → Daytime
# 2020-05-20 13:45:00 → Daytime
# 2020-05-20 14:00:00 → Daytime
# 2020-05-20 14:15:00 → Daytime
# 2020-05-20 14:30:00 → Daytime
# 2020-05-20 14:45:00 → Daytime
# 2020-05-20 15:00:00 → Daytime
# 2020-05-20 15:15:00 → Daytime
# 2020-05-20 15:30:00 → Daytime
# 2020-05-20 15:45:00 → Daytime
# 2020-05-20 16:00:00 → Daytime
# 2020-05-20 16:15:00 → Daytime
# 2020-05-20 16:30:00 → Daytime
# 2020-05-20 16:45:00 → Daytime
# 2020-05-20 17:00:00 → Daytime
# 2020-05-20 17:15:00 → Daytime
# 2020-05-21 00:45:00 → Night
# 2020-05-21 01:00:00 → Night
# 2020-05-21 01:15:00 → Night
# 2020-05-21 01:30:00 → Night
# 2020-05-21 01:45:00 → Night
# 2020-05-21 02:00:00 → Night
# 2020-05-21 02:15:00 → Night
# 2020-05-21 02:30:00 → Night
# 2020-05-21 02:45:00 → Night
# 2020-05-21 03:00:00 → Night
# 2020-05-21 03:15:00 → Night
# 2020-05-21 03:30:00 → Night
# 2020-05-21 03:45:00 → Night
# 2020-05-21 04:00:00 → Night
# 2020-05-21 04:15:00 → Night
# 2020-05-21 04:30:00 → Night
# 2020-05-21 04:45:00 → Night
# 2020-05-21 05:00:00 → Night
# 2020-05-21 05:15:00 → Night
# 2020-05-21 05:30:00 → Night
# 2020-05-21 05:45:00 → Night
# 2020-05-21 06:00:00 → Daytime
# 2020-05-21 06:15:00 → Daytime
# 2020-05-21 06:30:00 → Daytime
# 2020-05-21 06:45:00 → Daytime
# 2020-05-21 07:00:00 → Daytime
# 2020-05-21 07:15:00 → Daytime
# 2020-05-21 07:30:00 → Daytime
# 2020-05-23 05:30:00 → Night
# 2020-05-23 05:45:00 → Night
# 2020-05-23 06:00:00 → Daytime
# 2020-05-23 06:15:00 → Daytime
# 2020-05-23 06:30:00 → Daytime
# 2020-05-23 21:45:00 → Night
# 2020-05-29 02:00:00 → Night
# 2020-05-29 02:15:00 → Night
# 2020-05-29 02:30:00 → Night
# 2020-05-29 02:45:00 → Night
# 2020-05-29 03:00:00 → Night
# 2020-05-29 03:15:00 → Night
# 2020-05-29 03:30:00 → Night
# 2020-05-29 03:45:00 → Night
# 2020-05-29 04:00:00 → Night
# 2020-05-29 04:15:00 → Night
# 2020-05-29 04:30:00 → Night
# 2020-05-29 04:45:00 → Night
# 2020-05-29 05:00:00 → Night
# 2020-05-29 05:15:00 → Night
# 2020-05-29 05:30:00 → Night
# 2020-05-29 05:45:00 → Night
# 2020-05-29 06:00:00 → Daytime
# 2020-06-03 14:00:00 → Daytime

# %% [markdown]
# <h3 style='color:blue'> 視覺化 </h3>
# <p> 主要針對原始df_plant1資料 </p>

# %%
# numeric_columns = df_plant1.select_dtypes(include=np.number).columns.tolist() # 選取數值欄位
feature_columns = ['TIME_SIN', 'TIME_COS', 'IRRADIATION', 'AMBIENT_TEMPERATURE', 'MODULE_TEMPERATURE', 'DC_POWER']
corr_df = df_plant1[feature_columns].corr() # 計算相關係數矩陣 # numeric_columns
# mask = np.triu(np.ones_like(corr_df, dtype=bool), k=1) # 建立遮罩（只顯示下三角）
plt.figure(figsize=(10, 8))
sns.heatmap(corr_df, annot=True, cmap='coolwarm', linewidths=0.5) # mask=mask
plt.title('Correlation Heatmap')
plt.xticks(rotation=45, horizontalalignment='right', fontsize=10)
plt.yticks(rotation=0, horizontalalignment='right', fontsize=10)
plt.tight_layout()
plt.savefig(r'.\預測結果圖\Plant1第一號發電機組\Correlation Heatmap.png')
plt.show()

# %%
corr_df['DC_POWER'].sort_values(ascending=False)
# Out:
# DC_POWER               1.000000
# IRRADIATION            0.995971
# MODULE_TEMPERATURE     0.961106
# AMBIENT_TEMPERATURE    0.726899
# TIME_SIN              -0.023468
# TIME_COS              -0.860513
# Name: DC_POWER, dtype: float64

# %% [markdown]
# <p> DC_POWER </p>

# %%
def DC_Trend_Over_Time(df_plant1):
    plt.figure(figsize=(12, 6))

    # Daily yield plot (Daily Yield 折線圖)，顯示整體發電趨勢。
    df_plant1['DC_POWER'].plot(color='navy') # 用 index 當作 x 軸（不需指定 x）
    plt.title('DC Power Trend Over Time', fontsize=16)
    plt.ylabel('kW', color='navy', fontsize=14)
    plt.xlabel('Date Time', fontsize=14)
    plt.xticks(rotation=45)
    plt.tick_params(axis='both', which='major', labelsize=10)
    plt.tight_layout()
    plt.savefig(r'.\預測結果圖\Plant1第一號發電機組\DC Power Trend Over Time.png')
    plt.show()

DC_Trend_Over_Time(df_plant1)

# %%
def DC_During_Hours(df_plant1):
    fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(20, 5))

    # 左：散點圖
    ax1.plot(df_plant1['HOUR'], df_plant1['DC_POWER'], '.', alpha=0.5, label='DC_POWER')
    ax1.set_title('DC Power Distribution by Hour', fontsize=14)
    ax1.set_xlabel('Hour of Day', fontsize=12)
    ax1.set_ylabel('Power (kW)', fontsize=12)
    ax1.legend() # 圖例
    ax1.grid(True, alpha=0.3)

    # 右：長條圖（總功率）
    # 按照 HOUR 分組並計算DC_POWER功率
    hourly_sum = df_plant1.groupby('HOUR')['DC_POWER'].sum() # mean()
    hourly_sum.plot(kind='bar', color='navy', ax=ax2)
    ax2.set_title('Total DC Power Output by Hour', fontsize=14) # Average DC Power by Hour
    ax2.set_xlabel('Hour of Day', fontsize=12)
    ax2.set_ylabel('Total Power (kW)', fontsize=12)
    ax2.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.savefig(r'.\預測結果圖\Plant1第一號發電機組\DC Power by Hour.png')
    plt.show()

DC_During_Hours(df_plant1)

# %% [markdown]
# <p> Irradiation </p>

# %%
def Irradiation_By_Hour(df_plant1):
    fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(20, 5))

    # 散點圖：光照量 vs 小時
    # 光照量（IRRADIATION） vs 時間（TIME），呈現一天內各時刻的光照強度分佈。
    df_plant1.plot(x='HOUR', y='IRRADIATION', ax=ax1, style='o', color='coral', alpha=0.7)
    ax1.set_title('Irradiation During Day Hours', fontsize=14)
    ax1.set_ylabel('W/m²', fontsize=12)
    ax1.set_xlabel('Hour', fontsize=12)
    ax1.tick_params(axis='both', which='major', labelsize=10)
    ax1.legend(['Irradiation'], fontsize=10)
    ax1.grid(alpha=0.3)

    # 長條圖：每小時平均光照量
    irradiation_by_hour = df_plant1.groupby('HOUR')['IRRADIATION'].mean() # 按照 HOUR 分組並計算IRRADIATION太陽日照
    irradiation_by_hour.plot(kind='bar', ax=ax2, color='darkorange')
    ax2.set_title('Average Irradiation by Hour', fontsize=14)
    ax2.set_ylabel('W/m²', fontsize=12)
    ax2.set_xlabel('Hour of Day', fontsize=12)
    ax2.tick_params(axis='both', labelsize=10)
    ax2.legend(['Average Irradiation'], fontsize=10)
    ax2.grid(alpha=0.3)

    plt.tight_layout()
    plt.savefig(r'.\預測結果圖\Plant1第一號發電機組\Irradiation by Hour.png')
    plt.show()

Irradiation_By_Hour(df_plant1)

# %% [markdown]
# temperature

# %%
def plot_temperature(df_plant1):
    plt.figure(figsize=(12, 6))

    # 太陽能模組表面溫度 vs 環境氣溫。
    df_plant1[['AMBIENT_TEMPERATURE', 'MODULE_TEMPERATURE']].plot(ax=plt.gca()) # (ax=plt.gca())
    plt.title('Ambient and Module Temperature', fontsize=14)
    plt.ylabel('Temperature (°C)', fontsize=12)
    plt.xlabel('Date Time', fontsize=12)
    plt.tick_params(axis='both', which='major', labelsize=10)
    plt.legend(fontsize=10)
    plt.grid(alpha=0.3)
    plt.tight_layout()
    plt.savefig(r'.\預測結果圖\Plant1第一號發電機組\Ambient and Module Temperature.png')
    plt.show()

plot_temperature(df_plant1)

# %%
def temperature_during_DayHours(df_plant1):
    fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(20, 5))

    # 左圖：散點圖
    ax1.scatter(df_plant1['HOUR'], df_plant1['MODULE_TEMPERATURE'], alpha=0.6, label='Module Temp',  color='coral')
    ax1.scatter(df_plant1['HOUR'], df_plant1['AMBIENT_TEMPERATURE'], alpha=0.6, label='Ambient Temp', color='royalblue')
    ax1.set_title('Temperature by Hour', fontsize=14)
    ax1.set_xlabel('Hour', fontsize=12)
    ax1.set_ylabel('Temperature (°C)', fontsize=12)
    ax1.grid(alpha=0.3)
    ax1.legend()

    # 右圖：趨勢圖
    avg_temp = df_plant1.groupby('HOUR')[['MODULE_TEMPERATURE', 'AMBIENT_TEMPERATURE']].mean()
    ax2.plot(avg_temp.index, avg_temp['MODULE_TEMPERATURE'], color='coral', label='Module Temp', marker='o')
    ax2.plot(avg_temp.index, avg_temp['AMBIENT_TEMPERATURE'], color='royalblue', label='Ambient Temp', marker='o')
    ax2.set_title('Average Temperature by Hour', fontsize=14)
    ax2.set_xlabel('Hour', fontsize=12)
    ax2.set_ylabel('Temperature (°C)', fontsize=12)
    ax2.grid(alpha=0.3)
    ax2.legend()

    plt.tight_layout()
    plt.savefig(r'.\預測結果圖\Plant1第一號發電機組\Temperature by Hour.png')
    plt.show()

temperature_during_DayHours(df_plant1)

# %%
# 繪製時間序列數據及其異常值（outliers）的函數。
def plot_outlier(ts, n_column, ewm_span=100, threshold=3.0):
    os.makedirs('feature', exist_ok=True) 
    '''
    利用 指數加權移動平均（EWMA） 來檢測異常。
    1.) ts：需要檢測異常值的時間序列資料，應該是 pandas.Series 型態。
    2.) n_column：圖表的標題，通常是欄位名稱，用來指明是哪個特徵（feature）。
    3.) ewm_span：控制指數加權移動平均的平滑度，越高的值使平滑效果越強（默認為 100）。
    4.) threshold：異常值的檢測閾值，以標準差為單位，默認為 3.0，即數值偏離均值超過 3 個標準差會被認為是異常值。
    '''
    assert type(ts) == pd.Series # 確保 ts 是一個 pandas.Series 型態，否則會報錯。
    fig, ax = plt.subplots(figsize=(15,5)) # 建立圖表，並設置圖表大小為 15x5。
    ewm_mean = ts.ewm(span=ewm_span).mean()  # 計算時間序列的指數加權移動平均值（EWMA）。
    ewm_std = ts.ewm(span=ewm_span).std()  # 計算時間序列的指數加權標準差，用來判斷異常值。
    ax.plot(ts, label='original') # 繪製原始時間序列數據。
    ax.plot(ewm_mean, label='ewma') # 繪製指數加權移動平均線，提供平滑的數據趨勢。

    # plot data which deviate from range during mean ±  3 * std as outlier 
    ax.fill_between(ts.index,
                    ewm_mean - ewm_std * threshold,
                    ewm_mean + ewm_std * threshold,
                    alpha=0.2) # 填充一個區域，範圍為平均值加減 3 倍標準差（可以根據 threshold 調整），用來表示「正常區域」。位於此區域外的數據將視為異常值。
    outlier = ts[(ts - ewm_mean).abs() > ewm_std * threshold] # 篩選出超出正常區域的異常值。
    ax.scatter(outlier.index, outlier, label='outlier') # 使用散點圖標記異常值的位置。
    ax.legend() # 添加圖例，標示出原始數據、移動平均線和異常值。
    plt.title(n_column) # 設置圖表標題為指定的欄位名稱（n_column）。
    plt.savefig(f'feature/{n_column}.png') # 儲存圖表

# %%
# save feature plot 
for n_column in df_plant1.columns:
    plot_outlier(df_plant1[n_column], n_column)

# %% [markdown]
# <h4 style='color:blue'> Feature Importance 特徵重要性 </h4>

# %% [markdown]
# <p> train_test_split 切分資料 </p>

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.inspection import permutation_importance

# %%
target_col = 'DC_POWER' # 'AC_POWER'
# feature_cols = [col for col in df_plant1.columns if col not in [target_col]] # ['TIME', 'AMBIENT_TEMPERATURE', 'MODULE_TEMPERATURE', 'IRRADIATION']
feature_cols = ['TIME_SIN', 'TIME_COS', 'IRRADIATION', 'AMBIENT_TEMPERATURE', 'MODULE_TEMPERATURE']
feature_cols
# Out:
# ['TIME_SIN',
#  'TIME_COS',
#  'IRRADIATION',
#  'AMBIENT_TEMPERATURE',
#  'MODULE_TEMPERATURE']

# %%
# 製作 X 和 y
X = df_plant1[feature_cols]
y = df_plant1[target_col]

# 切分資料
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, shuffle=False)

# %% [markdown]
# <p style='color:blue'> Random Forest 進行分析 </p>

# %%
rf = RandomForestRegressor()
rf.fit(X_train, y_train)

importances = rf.feature_importances_
feature_importance = pd.DataFrame({
    'Feature': feature_cols,
    'Importance': importances
}).sort_values(by='Importance', ascending=False)

feature_importance
# Out:
#                Feature  Importance
# 2          IRRADIATION    0.996652
# 4   MODULE_TEMPERATURE    0.001213
# 3  AMBIENT_TEMPERATURE    0.000841
# 0             TIME_SIN    0.000787
# 1             TIME_COS    0.000507

# %%
feature_importance = feature_importance.sort_values(by='Importance', ascending=False) # 排序

plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=feature_importance, palette='viridis') # 使用色彩分層突顯重要性

plt.title('Feature Importance (Random Forest)', fontsize=14)
plt.xlabel('Importance Score', fontsize=12)
plt.ylabel('Feature', fontsize=12)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig(r'.\預測結果圖\Plant1第一號發電機組\Feature Importance (Random Forest).png')
plt.show()
# Out:
# C:\Users\HoChePing\AppData\Local\Temp\ipykernel_28428\4232395739.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Importance', y='Feature', data=feature_importance, palette='viridis') # 使用色彩分層突顯重要性

# %% [markdown]
# <p> Permutation Importance（特徵擾動重要性）=> 原理：逐一打亂每個特徵，觀察模型性能下降程度。</p>

# %%
model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X_train, y_train)
result = permutation_importance(model, X_val, y_val, n_repeats=10, random_state=42)
importance = pd.DataFrame({'feature': feature_cols, 'importance': result.importances_mean})
importance.sort_values(by='importance', ascending=False)
# Out:
#                feature  importance
# 2          IRRADIATION    1.945108
# 0             TIME_SIN    0.000775
# 1             TIME_COS    0.000358
# 4   MODULE_TEMPERATURE    0.000274
# 3  AMBIENT_TEMPERATURE   -0.000352

# %% [markdown]
# <p style='color:blue'> Lasso 進行分析 => 讓某些不重要的特徵係數變成 0（即直接剔除）。 </p>

# %% [markdown]
# <p> 本分析使用 Lasso 作為一種線性模型基礎上的特徵篩選，僅供對資料集結構之初步了解，後續仍以非線性模型如 LSTM/xLSTM 為主進行建模與重要性評估。 </p>

# %%
# 預測目標欄位
target_col = 'DC_POWER' # 'AC_POWER'
# feature_cols = [col for col in df_plant1.columns if col not in [target_col, 'DATE_TIME']]  # ['TIME', 'AMBIENT_TEMPERATURE', 'MODULE_TEMPERATURE', 'IRRADIATION'] 
feature_cols = ['TIME_SIN', 'TIME_COS', 'IRRADIATION', 'AMBIENT_TEMPERATURE', 'MODULE_TEMPERATURE']
feature_cols
# Out:
# ['TIME_SIN',
#  'TIME_COS',
#  'IRRADIATION',
#  'AMBIENT_TEMPERATURE',
#  'MODULE_TEMPERATURE']

# %%
# 分離 X 和 y
X = df_plant1[feature_cols].values
y = df_plant1[target_col].values.reshape(-1, 1)

# %%
from sklearn.linear_model import Lasso
from sklearn.preprocessing import StandardScaler

# 標準化
x_scaler = StandardScaler()
y_scaler = StandardScaler()

X_scaled = x_scaler.fit_transform(X)
y_scaled = y_scaler.fit_transform(y).ravel()  # 需降維為一維陣列

# %%
# 建立 Lasso 模型
model = Lasso(alpha=0.001)
model.fit(X_scaled, y_scaled)

# 抓取特徵名稱與權重
coeff = pd.Series(model.coef_, index=feature_cols)
coeff = coeff.sort_values(ascending=False)
coeff
# Out:
# IRRADIATION            0.944543
# AMBIENT_TEMPERATURE   -0.000000
# MODULE_TEMPERATURE     0.000000
# TIME_SIN              -0.005846
# TIME_COS              -0.059404
# dtype: float64

# %%
# 繪圖
plt.figure(figsize=(10, 6))
sns.barplot(x=coeff, y=coeff.index)
plt.title('Feature Importances for Predicting Energy Power (Standardized)')
plt.xlabel('Coefficient (Weight)')
plt.ylabel('Features')
plt.tight_layout()
plt.savefig(r'.\預測結果圖\Plant1第一號發電機組\Feature Importance (Lasso).png')
plt.show()

# %% [markdown]
# <h3 style='color:blue'> 資料前處理 </h3>

# %% [markdown]
# | 類別 | 時間範圍                    |
# | -- | ----------------------- |
# | 白天 | 06:00:00 ～ 18:30:00     |
# | 晚上 | 18:45:00 ～ 05:45:00（次日） |

# %% [markdown]
# <ol> 補值
#     <li> 針對 2020-06-17 06:15:00 及 2020-06-17 06:30:00 這兩個日期補發電資料。 </li>
#     <li> 採用插補法 </li>
# </ol>

# %%
df_plant1.columns
# Out:
# Index(['HOUR', 'MINUTE', 'MINUTES_PASS', 'TIME_SIN', 'TIME_COS', 'IRRADIATION',
#        'AMBIENT_TEMPERATURE', 'MODULE_TEMPERATURE', 'DC_POWER'],
#       dtype='object')

# %%
df_plant1.loc[[pd.to_datetime("2020-06-17 06:15"), 
               pd.to_datetime("2020-06-17 06:30")], 'DC_POWER'] = np.nan

# %%
# 使用 時間為基礎的方式補值
df_plant1['DC_POWER'] = df_plant1['DC_POWER'].interpolate(method='time') # 進行插值（只會補 NaN，不影響其他值）

# %% [markdown]
# <p> 使用 .resample('15T') 重新補齊缺漏的時間戳記 </p>

# %%
# 這裡只是要補時間點，因此使用 asfreq() 或 keep NaN
df_plant1  = df_plant1.resample('15T').asfreq()
df_plant1 = encode_time_features(df_plant1) # Time 分離出時間
df_plant1
# Out:
# C:\Users\HoChePing\AppData\Local\Temp\ipykernel_28428\2414593299.py:2: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   df_plant1  = df_plant1.resample('15T').asfreq()
#                      HOUR  MINUTE  MINUTES_PASS  TIME_SIN  TIME_COS  \
# DATE_TIME
# 2020-05-15 00:00:00     0       0             0  0.000000  1.000000
# 2020-05-15 00:15:00     0      15            15  0.065403  0.997859
# 2020-05-15 00:30:00     0      30            30  0.130526  0.991445
# 2020-05-15 00:45:00     0      45            45  0.195090  0.980785
# 2020-05-15 01:00:00     1       0            60  0.258819  0.965926
# ...                   ...     ...           ...       ...       ...
# 2020-06-17 22:45:00    22      45          1365 -0.321439  0.946930
# 2020-06-17 23:00:00    23       0          1380 -0.258819  0.965926
# 2020-06-17 23:15:00    23      15          1395 -0.195090  0.980785
# 2020-06-17 23:30:00    23      30          1410 -0.130526  0.991445
# 2020-06-17 23:45:00    23      45          1425 -0.065403  0.997859
#
#                      IRRADIATION  AMBIENT_TEMPERATURE  MODULE_TEMPERATURE  \
# DATE_TIME
# 2020-05-15 00:00:00          0.0            25.184316           22.857507
# 2020-05-15 00:15:00          0.0            25.084589           22.761668
# 2020-05-15 00:30:00          0.0            24.935753           22.592306
# 2020-05-15 00:45:00          0.0            24.846130           22.360852
# 2020-05-15 01:00:00          0.0            24.621525           22.165423
# ...                          ...                  ...                 ...
# 2020-06-17 22:45:00          0.0            22.150570           21.480377
# 2020-06-17 23:00:00          0.0            22.129816           21.389024
# 2020-06-17 23:15:00          0.0            22.008275           20.709211
# 2020-06-17 23:30:00          0.0            21.969495           20.734963
# 2020-06-17 23:45:00          0.0            21.909288           20.427972
#
#                      DC_POWER
# DATE_TIME
# 2020-05-15 00:00:00       0.0
# 2020-05-15 00:15:00       0.0
# 2020-05-15 00:30:00       0.0
# 2020-05-15 00:45:00       0.0
# 2020-05-15 01:00:00       0.0
# ...                       ...
# 2020-06-17 22:45:00       0.0
# 2020-06-17 23:00:00       0.0
# 2020-06-17 23:15:00       0.0
# 2020-06-17 23:30:00       0.0
# 2020-06-17 23:45:00       0.0
#
# [3264 rows x 9 columns]

# %% [markdown]
# 選擇性補值

# %% [markdown]
# 先填補氣象數據

# %%
env_cols = ['AMBIENT_TEMPERATURE', 'MODULE_TEMPERATURE', 'IRRADIATION'] # 氣象欄位(溫度)

df_plant1[env_cols] = (
    df_plant1[env_cols]
    .interpolate(method='time') # 插補為主：根據時間推估缺值
    .fillna(method='ffill') # 前向補值備援（處理開頭）
    .fillna(method='bfill') # 後向補值備援（處理結尾）
)
# Out:
# C:\Users\HoChePing\AppData\Local\Temp\ipykernel_28428\3851843372.py:4: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_plant1[env_cols]

# %% [markdown]
# 再填補發電資料(DC_POWER)

# %%
 # 加上 Day/Night 標籤
df_plant1['day_night'] = df_plant1.index.map(classify_day_night)

# 夜晚 → 缺失補 0
df_plant1.loc[(df_plant1['day_night'] == 'Night') & (df_plant1['DC_POWER'].isna()), 'DC_POWER'] = 0 

# 白天 → 缺失補插值
df_plant1.loc[df_plant1['day_night'] == 'Daytime', 'DC_POWER'] = (
    df_plant1.loc[df_plant1['day_night'] == 'Daytime', 'DC_POWER'].interpolate(method='time')
)

# %%
df_plant1.drop(columns=['day_night'], inplace=True)

# %%
df_plant1.isnull().sum()
# Out:
# HOUR                   0
# MINUTE                 0
# MINUTES_PASS           0
# TIME_SIN               0
# TIME_COS               0
# IRRADIATION            0
# AMBIENT_TEMPERATURE    0
# MODULE_TEMPERATURE     0
# DC_POWER               0
# dtype: int64

# %% [markdown]
# <h3 style='color:blue'> Scaler 標準化 </h3>

# %% [markdown]
# <ol> StandardScaler vs MinMaxScaler
#     <li> StandardScaler => 將數據轉為平均值為 0、標準差為 1；中心化、會忽略最小最大值的意義。 </li>
#     <li> MinMaxScaler => 將數據縮放至 [0, 1] 範圍；保留原本極小與極大值比例，不會扭曲數據結構。 </li>
# </ol>

# %% [markdown]
# <ol> 各欄位的Scaler方式
#     <li style='color:red'> TIME_SIN, TIME_COS => 不需再標準化，值本身已落在 [-1, 1] </li>
#     <li> MINUTES_PASS => 不建議 同時使用 MINUTES_PASS 和 TIME_SIN / TIME_COS 作為 LSTM 模型的特徵輸入，會造成資訊重複（collinearity），讓模型混淆，造成不穩定學習，因此刪除HOUR, MINUTE, MINUTES_PASS欄位。 </li>
#     <li> HOUR, MINUTE => 不建議直接使用，且TIME_SIN, TIME_COS 已經存在，就可以 完全捨棄 HOUR、MINUTE（它們的資訊已被 sin/cos 包含） </li>
#     <li style='color:red'> MODULE_TEMPERATURE =>  太陽能板的面板溫度，範圍落在18~65，趨勢較劇烈波動，使用 MinMaxScaler()。 </li>
#     <li style='color:green'> MODULE_TEMPERATURE在日照強時會急遽上升至 60°C 以上，一旦日落會快速掉回 20°C 左右，這種「快速上升／下降的波形」，類似太陽能功率曲線（如 DC_POWER）。 </li>
#     <li style='color:red'> IRRADIATION => 光照強度，是影響發電量（DC_POWER）最直接的氣象因子。呈現對稱鐘形分布，高峰落在中午（10:00–13:00）。使用 MinMaxScaler()。 </li>
#     <li style='color:green'> MODULE_TEMPERATUR、IRRADIATION => 同樣屬於光照驅動變數，建議統一處理方式，使用 MinMaxScaler()。 </li>
#     <li style='color:green'> 使用 StandardScaler() 會將高峰值「去中心化」，模型可能學不到中午是最強發電時段。 </li>
#     <li style='color:red'> DC_POWER => 太陽能板產生的直流功率，使用 MinMaxScaler()。 </li>
# </ol>

# %% [markdown]
# | 特徵欄位                   | 描述說明                         | Scaler 建議          | 說明理由                                       |
# |----------------------------|----------------------------------|----------------------|------------------------------------------------|
# | `TIME_SIN`, `TIME_COS`     | 時間週期性特徵（一天內位置）              | ❌ 不需標準化         | Sin/Cos 原本就落在 \[-1, 1]，不需再正規化             |
# | `MODULE_TEMPERATURE`       | 太陽能板面板溫度，範圍約 18–65°C         | ✅ `MinMaxScaler()` | 劇烈波動，建議壓縮到 \[0, 1]，利於模型收斂               |
# | `IRRADIATION`              | 太陽輻射量，呈鐘形分布，高峰落在上午10–13時 | ✅ `MinMaxScaler()` | 與發電強烈正相關，值範圍有限且無負值，適合 MinMax 壓縮   |
# | `DC_POWER`                 | 預測目標：太陽能板產生的直流功率           | ✅ `MinMaxScaler()` | 輸出值非負且最大值遠大，建議壓縮以穩定模型訓練             |

# %% [markdown]
# | 欄位名            | 原因                         |
# | -------------- | -------------------------- |
# | `HOUR`         | 可被 `TIME_SIN/COS` 完全取代     |
# | `MINUTE`       | 時間粒度太細，與 `TIME_SIN/COS` 重複 |
# | `MINUTES_PASS` | 只作為週期轉換的中介，不需保留            |

# %% [markdown]
# ~~AMBIENT_TEMPERATURE => 廠區環境溫度，範圍落在20~35，趨勢較緩變、穩定，使用 StandardScaler()。~~
#
#  ↑ 這點我無法確定！

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
df_plant1.drop(columns=['HOUR', 'MINUTE', 'MINUTES_PASS'], inplace=True)

# %%
df_plant1.columns
# Out:
# Index(['TIME_SIN', 'TIME_COS', 'IRRADIATION', 'AMBIENT_TEMPERATURE',
#        'MODULE_TEMPERATURE', 'DC_POWER'],
#       dtype='object')

# %%
# 預測目標欄位
target_col = 'DC_POWER' 
cyclic_cols = ['TIME_SIN', 'TIME_COS'] # 不進行標準化
scaler_cols = ['IRRADIATION', 'AMBIENT_TEMPERATURE', 'MODULE_TEMPERATURE'] # 建議使用 MinMaxScaler

# %%
# 建立 scaler 並 fit_transform 特徵欄位
feature_scaler = MinMaxScaler() # 將數據縮放到一個固定範圍內（例如 [0, 1]）。
df_plant1[scaler_cols] = feature_scaler.fit_transform(df_plant1[scaler_cols]) # 正規化數據

# 處理目標變數
target_scaler = MinMaxScaler() # 將數據縮放到一個固定範圍內（例如 [0, 1]）。
df_plant1[target_col] = target_scaler.fit_transform(df_plant1[[target_col]]) # 正規化數據

df_plant1
# Out:
#                      TIME_SIN  TIME_COS  IRRADIATION  AMBIENT_TEMPERATURE  \
# DATE_TIME
# 2020-05-15 00:00:00  0.000000  1.000000          0.0             0.322190
# 2020-05-15 00:15:00  0.065403  0.997859          0.0             0.315477
# 2020-05-15 00:30:00  0.130526  0.991445          0.0             0.305457
# 2020-05-15 00:45:00  0.195090  0.980785          0.0             0.299423
# 2020-05-15 01:00:00  0.258819  0.965926          0.0             0.284302
# ...                       ...       ...          ...                  ...
# 2020-06-17 22:45:00 -0.321439  0.946930          0.0             0.117953
# 2020-06-17 23:00:00 -0.258819  0.965926          0.0             0.116555
# 2020-06-17 23:15:00 -0.195090  0.980785          0.0             0.108373
# 2020-06-17 23:30:00 -0.130526  0.991445          0.0             0.105762
# 2020-06-17 23:45:00 -0.065403  0.997859          0.0             0.101709
#
#                      MODULE_TEMPERATURE  DC_POWER
# DATE_TIME
# 2020-05-15 00:00:00            0.099506       0.0
# 2020-05-15 00:15:00            0.097484       0.0
# 2020-05-15 00:30:00            0.093911       0.0
# 2020-05-15 00:45:00            0.089029       0.0
# 2020-05-15 01:00:00            0.084906       0.0
# ...                                 ...       ...
# 2020-06-17 22:45:00            0.070455       0.0
# 2020-06-17 23:00:00            0.068528       0.0
# 2020-06-17 23:15:00            0.054188       0.0
# 2020-06-17 23:30:00            0.054731       0.0
# 2020-06-17 23:45:00            0.048255       0.0
#
# [3264 rows x 6 columns]

# %% [markdown]
# <h4 style='color:blue'> 拆分資料 & Save Dataset </h4>
# 80%：訓練、20%：測試

# %%
df_plant1.to_csv(r'Merged Plant1 Data.csv')

# %%
y = df_plant1['DC_POWER'].values
pd.DataFrame(y, columns=['DC_POWER'], index=df_plant1.index)
# Out:
#                      DC_POWER
# DATE_TIME
# 2020-05-15 00:00:00       0.0
# 2020-05-15 00:15:00       0.0
# 2020-05-15 00:30:00       0.0
# 2020-05-15 00:45:00       0.0
# 2020-05-15 01:00:00       0.0
# ...                       ...
# 2020-06-17 22:45:00       0.0
# 2020-06-17 23:00:00       0.0
# 2020-06-17 23:15:00       0.0
# 2020-06-17 23:30:00       0.0
# 2020-06-17 23:45:00       0.0
#
# [3264 rows x 1 columns]

# %%
X = df_plant1.drop(['DC_POWER'], axis=1).values
pd.DataFrame(X, columns=df_plant1.columns[:-1], index=df_plant1.index)
# Out:
#                      TIME_SIN  TIME_COS  IRRADIATION  AMBIENT_TEMPERATURE  \
# DATE_TIME
# 2020-05-15 00:00:00  0.000000  1.000000          0.0             0.322190
# 2020-05-15 00:15:00  0.065403  0.997859          0.0             0.315477
# 2020-05-15 00:30:00  0.130526  0.991445          0.0             0.305457
# 2020-05-15 00:45:00  0.195090  0.980785          0.0             0.299423
# 2020-05-15 01:00:00  0.258819  0.965926          0.0             0.284302
# ...                       ...       ...          ...                  ...
# 2020-06-17 22:45:00 -0.321439  0.946930          0.0             0.117953
# 2020-06-17 23:00:00 -0.258819  0.965926          0.0             0.116555
# 2020-06-17 23:15:00 -0.195090  0.980785          0.0             0.108373
# 2020-06-17 23:30:00 -0.130526  0.991445          0.0             0.105762
# 2020-06-17 23:45:00 -0.065403  0.997859          0.0             0.101709
#
#                      MODULE_TEMPERATURE
# DATE_TIME
# 2020-05-15 00:00:00            0.099506
# 2020-05-15 00:15:00            0.097484
# 2020-05-15 00:30:00            0.093911
# 2020-05-15 00:45:00            0.089029
# 2020-05-15 01:00:00            0.084906
# ...                                 ...
# 2020-06-17 22:45:00            0.070455
# 2020-06-17 23:00:00            0.068528
# 2020-06-17 23:15:00            0.054188
# 2020-06-17 23:30:00            0.054731
# 2020-06-17 23:45:00            0.048255
#
# [3264 rows x 5 columns]

# %%
# 資料拆分比例
# 取前面80%為train，後面20%為test。
split_index = int(len(df_plant1) * 0.8)
split_index
# Out:
# 2611

# %%
# 時間序列切分（避免 shuffle）
X_train = X[:split_index]
y_train = y[:split_index]
X_test = X[split_index:]
y_test = y[split_index:]

# %%
# 儲存為 pkl
data_dic = {
    'X_train': X_train,
    'y_train': y_train,
    'X_test': X_test,
    'y_test': y_test,
}

# pkl檔案 用於儲存 Python 資料結構。
for key, value in data_dic.items():
    with open(f'{key}.pkl', 'wb') as f: # 使用 pickle.dump 將數據寫入文件，'wb' 表示二進制寫入。
        pickle.dump(value, f)

# %% [markdown]
# <h2> LSTM模型預測 </h2>

# %% [markdown]
# <ol>
#     <li> 使用前 60 分鐘的數據作為輸入 (X 陣列)，並以第75分鐘的DAILY_YIELD數據作為對應的輸出。 </li>
#     <li> 此方法採用滑動視窗（sliding window）的方式，持續向前移動視窗，讓模型學習隨時間變化的規律，從而能夠預測未來的時間區間內的產能變化。 </li>
# </ol>

# %%
#  Tensorflow imports
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, CSVLogger
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError as RMSE, mean_squared_error as mse, mean_absolute_error as mae
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import LSTM, Dense, InputLayer, Dropout
from tensorflow.keras.layers import TimeDistributed
from tensorflow.keras import initializers, regularizers # initializers → 初始化層的權重、regularizers → 對權重加入 L1/L2 正則化
from tensorflow.keras.utils import plot_model

from sklearn.metrics import r2_score

# %% [markdown]
# <h3> definition 函式庫 </h3>

# %%
#將時間序列數據轉換為適合LSTM訓練的輸入特徵 (X) 和標籤 (y)
def Sliding_Window(df, feature_cols, target_col='DC_POWER', window_size=5):  
    '''
    用每 5 個連續數據點預測下一個數據點（即前60分鐘的5組特徵，預測未來第75分鐘的發電量。）
    將時間序列數據轉換為 LSTM 所需的格式：
    X shape → (樣本數, 時間步長, 特徵數)
    y shape → (樣本數, 特徵數)
    '''
    X = []
    y = []
    feature_values = df[feature_cols].to_numpy()
    target_values = df[[target_col]].to_numpy()
    
    for i in range(len(df)-window_size): # 用長度為 window_size（預設 5）的小段序列當作輸入X，用下一個時間點的值作為預測目標y。
        X.append(feature_values[i:i+window_size]) # shape: (5, 特徵數)
        y.append(target_values[i+window_size]) # shape: (1,)
        
    return np.array(X), np.array(y)

# %%
def save_lr_curve(H, f_name=None):
    """
    save learning curve in deep learning

    Args:
        model : trained model (keras)
        out_dir (str): directory path for saving
    """
    f_name = 'Learning Curve' if not f_name else f'{f_name} Learning Curve' # 檔名
    plt.figure(figsize=(30, 10)) # 建立圖表
    plt.rcParams["font.size"] = 18 # 字體大小為 18。
    plt.plot(H.history['loss'], label='Train', marker='o', markersize=5) # 繪製訓練損失曲線
    plt.plot(H.history['val_loss'], label='Validation', marker='s', markersize=5) # 繪製驗證損失曲線
    # Add value annotations
    for i, value in enumerate(H.history['loss']):
        if i % 10 == 0:  # 每隔 10 個數據點標一次
            plt.annotate(f'{value:.4f}', xy=(i, value), xytext=(0, 5), textcoords='offset points', ha='center', va='bottom', fontsize=12, color='blue', alpha=0.9)
    for i, value in enumerate(H.history['val_loss']):
        if i % 10 == 0:  # 每隔 10 個數據點標一次
            plt.annotate(f'{value:.4f}', xy=(i, value), xytext=(0, -5), textcoords='offset points', ha='center', va='top', fontsize=12, color='orange', alpha=0.9)
    plt.title(f'{f_name} (Model Loss)', fontsize=18)
    plt.ylabel('Loss', fontsize=16)
    plt.xlabel('Epoch', fontsize=16)
    plt.legend(['Train', 'Validation'], loc='best', fontsize=14)
    plt.grid(alpha=0.3)  # 加入透明網格，便於觀察
    plt.tight_layout()
    plt.savefig(f".\預測結果圖\Plant1第一號發電機組\{f_name}.png", bbox_inches="tight")
    plt.show()
    # plt.close('all')  # 關閉所有繪圖對象
    print(f"Plot saved to .\預測結果圖\Plant1第一號發電機組\{f_name}.png")

# %%
def metric_score(y_test_time: np.array, y_pred_test_time: np.array, model=None):
    """
    save mean squared error for tareget variable

    Args:
        y_test_time (np.array): observed data for target variable # 實際值
        y_pred_test_time (np.array): predicted data for target variable # 預測值
        out_dir (str): directory path for saving # 保存目錄
        model : trained model (keras)
    """
    # sklearn
    mse_loss = mse(y_test_time, y_pred_test_time) # 計算均方誤差
    rmse_loss = np.sqrt(mse_loss)  # RMSE
    mae_loss = mae(y_test_time, y_pred_test_time) # 計算平均絕對誤差
    r2 = r2_score(y_test_time, y_pred_test_time)  # R-squared指標，反映模型解釋目標變數變異程度的能力。

    # Printing metrics
    print(f"Mean Squared Error (MSE): {mse_loss:.4f}")
    print(f"Root Mean Squared Error (RMSE): {rmse_loss:.4f}")
    print(f"Mean Absolute Error (MAE): {mae_loss:.4f}")
    print(f"R² Score: {r2:.4f}")

    with open(r'.\預測結果圖\Plant1第一號發電機組\log.txt', 'w') as f: # 寫入文件
        f.write('MAE預測誤差值 : {:.6f}\n'.format(mae_loss))
        f.write('MSE預測誤差值 : {:.6f}\n'.format(mse_loss))
        f.write('RMSE預測誤差值 : {:.6f}\n'.format(rmse_loss))        
        f.write('R2 Score : {:.6f}\n'.format(r2))
        f.write('=' * 65 + '\n')
        if model:
            model.summary(print_fn=lambda x: f.write(x + '\n')) # 將模型摘要資訊寫入文件。
            
    return mse_loss, rmse_loss, mae_loss, r2

# %%
def save_prediction_plot(y_test_time: np.array, y_pred_test_time: np.array, mode: str):
    """
    save prediction plot for tareget varibale

    Args:
        y_test_time (np.array): observed data for target variable # 實際值
        y_pred_test_time (np.array): predicted data for target variable # 預測值
    """
    plt.figure(figsize=(30, 10)) # 設定圖表大小
    plt.rcParams["font.size"] = 18 # 設置字體大小
    plt.plot([i for i in range(1, 1 + len(y_pred_test_time))], y_pred_test_time, color='red', label='Predicted Values', marker='x', markersize=2) # 繪製預測數據的紅色折線圖
    plt.plot([i for i in range(1, 1 + len(y_test_time))], y_test_time, color='blue', label='Actual Values', marker="o", markersize=2) # 繪製實際數據的藍色折線圖
    
    # 在每個點上顯示數據標籤 (預測數據)
    for i, value in enumerate(y_pred_test_time):
        if i % 100 == 0:  # 每隔 1000 個數據點顯示一次標籤
            plt.annotate(f'{value:.2f}', xy=(i, value), xytext=(0, 5), textcoords="offset points", ha='center', va='bottom', color='crimson', fontsize=12, alpha=0.9)
    # 在每個點上顯示數據標籤 (實際數據)
    for i, value in enumerate(y_test_time):
        if i % 100 == 0:  # 每隔 1000 個數據點顯示一次標籤
            plt.annotate(f'{value:.2f}', xy=(i, value),  xytext=(0, -5), textcoords="offset points", ha='center', va='top', color='dodgerblue', fontsize=12, alpha=0.9)
    
    plt.ylim(0, 1) # 設置y軸的顯示範圍為0到1。
    plt.xlim(0, len(y_test_time)) # 設置x軸範圍，從0到實際數據的長度。
    title = "Comparison of Actual and Predicted Values"
    plt.title(title)
    plt.ylabel('Value') # 設置y軸標籤。
    plt.xlabel('樣本序列') # 設置x軸標籤。
    plt.legend(loc="best") # 顯示圖例，並將圖例放在最佳位置（由 Matplotlib 自動確定）。
    plt.grid(alpha=0.3)  # 加入透明網格，便於觀察
    plt.tight_layout()
    plt.savefig(f'.\預測結果圖\Plant1第一號發電機組\{mode} prediction.png', bbox_inches='tight') # 保存圖像
    plt.show() # 顯示圖表
    # plt.close('all')  # 關閉所有繪圖對象
    print(f"Plot saved to .\預測結果圖\Plant1第一號發電機組\{mode} prediction.png")

# %%
# 誤差直方圖（Error Histogram）
def ErrorHistogram(y_test_time: np.array, y_pred_test_time: np.array):
    plt.figure(figsize=(12, 8))
    residuals = y_test_time - y_pred_test_time # 計算殘差
    plt.hist(residuals, bins='auto', color='deepskyblue', edgecolor='black', label='Residuals (y_test - y_pred)') # 柱狀圖，並讓Matplotlib自動計算bins區間。
    plt.axvline(x=0, color='red', linestyle='--', linewidth=2, label='Ideal Line (Residual = 0)') # 基準線，加一條紅色的垂直基準線，位於Residual為0的地方。
    # 填充Overestimation區域（Residual < 0）
    plt.axvspan(-1, 0, color='burlywood', alpha=0.2, label='OverEstimation Region (Residual < 0)')  # 當 Residual < 0 時，表示實際值 < 預測值（高估）。
    # 填充Underestimation區域（Residual > 0）
    plt.axvspan(0, 1, color='darkseagreen', alpha=0.2, label='UnderEstimation Region (Residual > 0)')  # 當 Residual > 0 時，表示實際值 > 預測值（低估）。
    title = 'Error Histogram 誤差直方圖'
    plt.title(title, fontsize=16)
    plt.xlabel('Residuals', fontsize=14)
    plt.ylabel('count', fontsize=14)
    plt.legend(loc='best', fontsize=12, frameon=True, edgecolor='black', fancybox=True)
    plt.tight_layout()
    plt.savefig(r'.\預測結果圖\Plant1第一號發電機組\Error Histogram.png', bbox_inches='tight') # 保存圖像
    plt.show()
    # plt.close('all')  # 關閉所有繪圖對象
    print(r"Plot saved to .\預測結果圖\Plant1第一號發電機組\Error Histogram.png")

# %%
def save_yy_plot(y_test_time: np.array, y_pred_test_time: np.array):
    """
    save yy plot for target variable

    Args:
        y_test_time (np.array): observed data for target variable # 實際值
        y_pred_test_time (np.array): predicted data for target variable # 預測值
        out_dir (str): directory path for saving # 保存目錄
    """
    plt.figure(figsize=(10, 10)) # 設定圖表大小
    plt.rcParams["font.size"] = 18 # 設置字體大小
    plt.plot(y_test_time, y_pred_test_time, 'b.', label='Predicted Values vs Actual Values') # 繪製預測值與實際值的散點圖，使用藍色點標記。
    diagonal = np.linspace(0, 1, 10000) # 繪製對角線
    plt.plot(diagonal, diagonal, 'r-', label='Ideal Line') # 繪製一條紅色的對角線，表示理想狀況下的預測值與實際值相等。散點越接近這條線，表示預測越準確。
    # Highlight regions for high and low estimates
    plt.fill_between(diagonal, diagonal, 1, color='peachpuff', alpha=0.2, label='Overestimation Region')  # 淺橙色區域 (color='peachpuff '): 表示模型的高估區域（y_pred_test_time > y_test_time）。
    plt.fill_between(diagonal, 0, diagonal, color='palegreen', alpha=0.2, label='Underestimation Region')  # 淺綠色區域 (color='peachpuff '): 表示模型的低估區域（y_pred_test_time < y_test_time）。
    plt.xlim(0, 1) # 設定x軸的範圍為0到1。
    plt.ylim(0, 1) # 設定y軸的範圍為0到1。
    title = '觀察值與預測值的對角線分析圖'
    plt.title(title, fontsize=16)
    plt.xlabel('Actual Values', fontsize=14) # 設置x軸標籤。
    plt.ylabel('Predicted Values', fontsize=14) # 設置y軸標籤。
    plt.legend(loc='best', fontsize=12) # Add legend
    plt.tight_layout()
    plt.savefig(r'.\預測結果圖\Plant1第一號發電機組\yy_plot.png', bbox_inches='tight') # 保存圖像
    plt.show()
    # plt.close('all')  # 關閉所有繪圖對象
    print(r"Plot saved to .\預測結果圖\Plant1第一號發電機組\yy_plot.png")

# %% [markdown]
# <h3> 資料處理 </h3>

# %%
#  讓 LSTM 學習 DC Power 這條曲線的變化趨勢。
feature_cols = ['TIME_SIN', 'TIME_COS', 'IRRADIATION', 'AMBIENT_TEMPERATURE', 'MODULE_TEMPERATURE']
target_col = 'DC_POWER'

X, y = Sliding_Window(df_plant1, feature_cols, target_col, window_size=5)
X.shape, y.shape
# Out:
# ((3259, 5, 5), (3259, 1))

# %%
X
# Out:
# array([[[ 0.        ,  1.        ,  0.        ,  0.32219047,
#           0.09950559],
#         [ 0.06540313,  0.99785892,  0.        ,  0.31547662,
#           0.09748388],
#         [ 0.13052619,  0.99144486,  0.        ,  0.30545668,
#           0.09391123],
#         [ 0.19509032,  0.98078528,  0.        ,  0.29942313,
#           0.0890288 ],
#         [ 0.25881905,  0.96592583,  0.        ,  0.28430226,
#           0.08490627]],
#
#        [[ 0.06540313,  0.99785892,  0.        ,  0.31547662,
#           0.09748388],
#         [ 0.13052619,  0.99144486,  0.        ,  0.30545668,
#           0.09391123],
#         [ 0.19509032,  0.98078528,  0.        ,  0.29942313,
#           0.0890288 ],
#         [ 0.25881905,  0.96592583,  0.        ,  0.28430226,
#           0.08490627],
#         [ 0.32143947,  0.94693013,  0.        ,  0.27855073,
#           0.08075375]],
#
#        [[ 0.13052619,  0.99144486,  0.        ,  0.30545668,
#           0.09391123],
#         [ 0.19509032,  0.98078528,  0.        ,  0.29942313,
#           0.0890288 ],
#         [ 0.25881905,  0.96592583,  0.        ,  0.28430226,
#           0.08490627],
#         [ 0.32143947,  0.94693013,  0.        ,  0.27855073,
#           0.08075375],
#         [ 0.38268343,  0.92387953,  0.        ,  0.28545674,
#           0.08886159]],
#
#        ...,
#
#        [[-0.5       ,  0.8660254 ,  0.        ,  0.14573026,
#           0.06379662],
#         [-0.44228869,  0.89687274,  0.        ,  0.12122838,
#           0.05009688],
#         [-0.38268343,  0.92387953,  0.        ,  0.11937754,
#           0.0620271 ],
#         [-0.32143947,  0.94693013,  0.        ,  0.11795254,
#           0.07045545],
#         [-0.25881905,  0.96592583,  0.        ,  0.11655534,
#           0.06852838]],
#
#        [[-0.44228869,  0.89687274,  0.        ,  0.12122838,
#           0.05009688],
#         [-0.38268343,  0.92387953,  0.        ,  0.11937754,
#           0.0620271 ],
#         [-0.32143947,  0.94693013,  0.        ,  0.11795254,
#           0.07045545],
#         [-0.25881905,  0.96592583,  0.        ,  0.11655534,
#           0.06852838],
#         [-0.19509032,  0.98078528,  0.        ,  0.10837295,
#           0.05418795]],
#
#        [[-0.38268343,  0.92387953,  0.        ,  0.11937754,
#           0.0620271 ],
#         [-0.32143947,  0.94693013,  0.        ,  0.11795254,
#           0.07045545],
#         [-0.25881905,  0.96592583,  0.        ,  0.11655534,
#           0.06852838],
#         [-0.19509032,  0.98078528,  0.        ,  0.10837295,
#           0.05418795],
#         [-0.13052619,  0.99144486,  0.        ,  0.10576221,
#           0.05473117]]])

# %%
y
# Out:
# array([[0.],
#        [0.],
#        [0.],
#        ...,
#        [0.],
#        [0.],
#        [0.]])

# %%
# making a train and test dataset to train the model

X_train, y_train  = X[:2600], y[:2600]
X_val, y_val  = X[2600:2900], y[2600:2900]
X_test, y_test  = X[2900:], y[2900:]

print(X_train.shape, y_train.shape)
print(X_val.shape, y_val.shape)
print(X_test.shape, y_test.shape)
# Out:
# (2600, 5, 5) (2600, 1)
# (300, 5, 5) (300, 1)
# (359, 5, 5) (359, 1)

# %% [markdown]
# <h3> 建構LSTM模型 </h3>

# %%
input_shape=(5, 5)
input_layer = Input(input_shape)

# %%
dense = TimeDistributed(
    Dense( 
        10, # 輸出單元數為10的全連接層。
        kernel_regularizer=regularizers.l2(0.01), # 正則化，減少模型的過度擬合。
        kernel_initializer=initializers.glorot_uniform(seed=0), # 使用 Glorot 均勻初始化方法對權重進行初始化，有助於提高模型的收斂速度和穩定性。
        bias_initializer=initializers.Zeros() # 將偏置初始化為 0。
    )
)(input_layer)

# %%
lstm1 = LSTM(
    60,
    return_sequences=True,
    kernel_regularizer=regularizers.l2(0.01), # 正則化，減少模型的過度擬合。
    kernel_initializer=initializers.glorot_uniform(seed=0), # 使用 Glorot 均勻初始化方法對權重進行初始化，有助於提高模型的收斂速度和穩定性。
    recurrent_initializer=initializers.Orthogonal(seed=0), # 將 LSTM 的遞歸權重初始化為正交矩陣，以促進梯度穩定。
    bias_initializer=initializers.Zeros() # 將偏置初始化為 0。
)(dense)
lstm1 = BatchNormalization()(lstm1) # 正規化，穩定訓練過程、加速收斂，並提高模型的泛化能力。

# %%
lstm2 = LSTM(
    60,
    return_sequences=False,
    kernel_regularizer=regularizers.l2(0.01), # 正則化，減少模型的過度擬合。
    kernel_initializer=initializers.glorot_uniform(seed=0), # 使用 Glorot 均勻初始化方法對權重進行初始化，有助於提高模型的收斂速度和穩定性。
    recurrent_initializer=initializers.Orthogonal(seed=0), # 將 LSTM 的遞歸權重初始化為正交矩陣，以促進梯度穩定。
    bias_initializer=initializers.Zeros() # 將偏置初始化為 0。
)(lstm1)
lstm2 = BatchNormalization()(lstm2) # 正規化，穩定訓練過程、加速收斂，並提高模型的泛化能力。

# %%
output_layer = Dense(
    1,
    activation='sigmoid', # 激活函數為sigmoid，適合輸出一個範圍在0到1之間的預測結果。
    kernel_regularizer=regularizers.l2(0.01), # 正則化，減少模型的過度擬合。
    kernel_initializer=initializers.glorot_uniform(seed=0), # 使用 Glorot 均勻初始化方法對權重進行初始化，有助於提高模型的收斂速度和穩定性。
    bias_initializer=initializers.Zeros() # 將偏置初始化為 0。
)(lstm2)

# %%
model = Model(inputs=input_layer, outputs=output_layer) # 建立模型

# %%
plot_model(model, to_file=r'.\預測結果圖\Plant1第一號發電機組\architecture.png', show_shapes=True, show_layer_names=True)

# %%
# Define the model checkpoint callback
# Save the best model based on validation loss (lowest RMSE)
model_checkpoint = ModelCheckpoint(
    filepath='model/best_model.hdf5',  # Use .h5 extension for model saving
    monitor='val_loss',
    save_best_only=True,
    verbose=1  # Print out saving messages
)

# Add early stopping to stop training if the model stops improving
early_stopping = EarlyStopping(
    monitor='val_loss',  # Stop if RMSE doesn't improve
    patience=10,  # Wait 10 epochs before stopping
    restore_best_weights=True,  # Restore the best weights after stopping
    verbose=1
)

# 定義 ReduceLROnPlateau 回調函數
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',  # 監控指標 (驗證集 RMSE)
    factor=0.5,  # 每次學習率減少的比例 (將學習率減半)
    patience=4,  # 若監控指標未改善，等待 5 個 epoch 再減少學習率
    min_lr=1e-7,  # 最低學習率限制
    verbose=1  # 顯示學習率調整的訊息
)

csv_logger = CSVLogger('.\預測結果圖\Plant1第一號發電機組\epoch_log.csv') # 將每個訓練週期的損失和評估指標記錄到 CSV 文件中

# %%
Adam_optimizer = Adam(learning_rate=1e-3) # 標準Adam優化器
print(f'優化器參數: {Adam_optimizer.get_config()}')
# Out:
# 優化器參數: {'name': 'Adam', 'learning_rate': 0.001, 'decay': 0.0, 'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-07, 'amsgrad': False}

# %%
model.compile(optimizer=Adam_optimizer, loss='mse', metrics=['mse', 'mae'])
print(model.summary())
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5, 5)]            0
#
#  time_distributed (TimeDistr  (None, 5, 10)            60
#  ibuted)
#
#  lstm (LSTM)                 (None, 5, 60)             17040
#
#  batch_normalization (BatchN  (None, 5, 60)            240
#  ormalization)
#
#  lstm_1 (LSTM)               (None, 60)                29040
#
#  batch_normalization_1 (Batc  (None, 60)               240
#  hNormalization)
#
#  dense_1 (Dense)             (None, 1)                 61
#
# =================================================================
# Total params: 46,681
# Trainable params: 46,441
# Non-trainable params: 240
# _________________________________________________________________
# None

# %%
# Fit the model with better structure, additional callbacks, and dynamic batch size
H = model.fit(
    X_train,
    y_train,
    validation_data=(X_val, y_val),  # Provide validation data for real-time evaluation
    epochs=500,  
    batch_size=128, # 也可以測試 32, 64, 128 比較效果
    callbacks=[model_checkpoint, early_stopping, reduce_lr, csv_logger],  
    verbose=1  # Show training progress
)

H
# Out:
# Epoch 1/500
# 15/21 [====================>.........] - ETA: 0s - loss: 1.2390 - mse: 0.0796 - mae: 0.2205
# Epoch 1: val_loss improved from inf to 1.07012, saving model to model\best_model.hdf5
# 21/21 [==============================] - 3s 27ms/step - loss: 1.1879 - mse: 0.0698 - mae: 0.2020 - val_loss: 1.0701 - val_mse: 0.1269 - val_mae: 0.3245 - lr: 0.0010
# Epoch 2/500
# 17/21 [=======================>......] - ETA: 0s - loss: 0.8726 - mse: 0.0407 - mae: 0.1532
# Epoch 2: val_loss improved from 1.07012 to 0.78289, saving model to model\best_model.hdf5
# 21/21 [==============================] - 0s 9ms/step - loss: 0.8506 - mse: 0.0398 - mae: 0.1526 - val_loss: 0.7829 - val_mse: 0.1114 - val_mae: 0.3064 - lr: 0.0010
# Epoch 3/500
# 16/21 [=====================>........] - ETA: 0s - loss: 0.6288 - mse: 0.0321 - mae: 0.1443
# Epoch 3: val_loss improved from 0.78289 to 0.57830, saving model to model\best_model.hdf5
# 21/21 [==============================] - 0s 9ms/step - loss: 0.6100 - mse: 0.0325 - mae: 0.1461 - val_loss: 0.5783 - val_mse: 0.0977 - val_mae: 0.2895 - lr: 0.0010
# Epoch 4/500
# 16/21 [=====================>........] - ETA: 0s - loss: 0.4603 - mse: 0.0306 - mae: 0.1401
# Epoch 4: val_loss improved from 0.57830 to 0.43788, saving model to model\best_model.hdf5
# 21/21 [==============================] - 0s 9ms/step - loss: 0.4467 - mse: 0.0300 - mae: 0.1396 - val_loss: 0.4379 - val_mse: 0.0869 - val_mae: 0.2742 - lr: 0.0010
# Epoch 5/500
# 17/21 [=======================>......] - ETA: 0s - loss: 0.3414 - mse: 0.0269 - mae: 0.1342
# Epoch 5: val_loss improved from 0.43788 to 0.34348, saving model to model\best_model.hdf5
# 21/21 [==============================] - 0s 9ms/step - loss: 0.3346 - mse: 0.0268 - mae: 0.1348 - val_loss: 0.3435 - val_mse: 0.0802 - val_mae: 0.2630 - lr: 0.0010
# Epoch 6/500
# 17/21 [=======================>......] - ETA: 0s - loss: 0.2620 - mse: 0.0235 - mae: 0.1275
# Epoch 6: val_loss improved from 0.34348 to 0.27879, saving model to model\best_model.hdf5
# 21/21 [==============================] - 0s 9ms/step - loss: 0.2571 - mse: 0.0231 - mae: 0.1281 - val_loss: 0.2788 - val_mse: 0.0751 - val_mae: 0.2523 - lr: 0.0010
# Epoch 7/500
# 17/21 [=======================>......] - ETA: 0s - loss: 0.2073 - mse: 0.0206 - mae: 0.1210
# Epoch 7: val_loss improved from 0.27879 to 0.23539, saving model to model\best_model.hdf5
# 21/21 [==============================] - 0s 9ms/step - loss: 0.2036 - mse: 0.0200 - mae: 0.1194 - val_loss: 0.2354 - val_mse: 0.0726 - val_mae: 0.2442 - lr: 0.0010
# Epoch 8/500
# 17/21 [=======================>......] - ETA: 0s - loss: 0.1669 - mse: 0.0160 - mae: 0.1078
# Epoch 8: val_loss improved from 0.23539 to 0.20558, saving model to model\best_model.hdf5
# 21/21 [==============================] - 0s 9ms/step - loss: 0.1652 - mse: 0.0164 - mae: 0.1095 - val_loss: 0.2056 - val_mse: 0.0715 - val_mae: 0.2387 - lr: 0.0010
# Epoch 9/500
# 15/21 [====================>.........] - ETA: 0s - loss: 0.1402 - mse: 0.0136 - mae: 0.0996
# Epoch 9: val_loss improved from 0.20558 to 0.18367, saving model to model\best_model.hdf5
# 21/21 [==============================] - 0s 9ms/step - loss: 0.1379 - mse: 0.0139 - mae: 0.1004 - val_loss: 0.1837 - val_mse: 0.0704 - val_mae: 0.2334 - lr: 0.0010
# Epoch 10/500
# 17/21 [=======================>......] - ETA: 0s - loss: 0.1220 - mse: 0.0149 - mae: 0.1011
# Epoch 10: val_loss improved from 0.18367 to 0.16700, saving model to model\best_model.hdf5
# 21/21 [==============================] - 0s 9ms/step - loss: 0.1203 - mse: 0.0144 - mae: 0.0981 - val_loss: 0.1670 - val_mse: 0.0689 - val_mae: 0.2287 - lr: 0.0010
# Epoch 11/500
# 21/21 [==============================] - ETA: 0s - loss: 0.1038 - mse: 0.0115 - mae: 0.0887
# Epoch 11: val_loss improved from 0.16700 to 0.15493, saving model to model\best_model.hdf5
# 21/21 [==============================] - 0s 10ms/step - loss: 0.1038 - mse: 0.0115 - mae: 0.0887 - val_loss: 0.1549 - val_mse: 0.0690 - val_mae: 0.2275 - lr: 0.0010
# Epoch 12/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0929 - mse: 0.0114 - mae: 0.0851
# Epoch 12: val_loss improved from 0.15493 to 0.14647, saving model to model\best_model.hdf5
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0927 - mse: 0.0115 - mae: 0.0862 - val_loss: 0.1465 - val_mse: 0.0705 - val_mae: 0.2294 - lr: 0.0010
# Epoch 13/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0826 - mse: 0.0103 - mae: 0.0811
# Epoch 13: val_loss improved from 0.14647 to 0.13802, saving model to model\best_model.hdf5
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0826 - mse: 0.0105 - mae: 0.0817 - val_loss: 0.1380 - val_mse: 0.0703 - val_mae: 0.2283 - lr: 0.0010
# Epoch 14/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0772 - mse: 0.0125 - mae: 0.0885
# Epoch 14: val_loss improved from 0.13802 to 0.12820, saving model to model\best_model.hdf5
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0769 - mse: 0.0123 - mae: 0.0877 - val_loss: 0.1282 - val_mse: 0.0673 - val_mae: 0.2223 - lr: 0.0010
# Epoch 15/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0682 - mse: 0.0101 - mae: 0.0783
# Epoch 15: val_loss improved from 0.12820 to 0.12375, saving model to model\best_model.hdf5
# 21/21 [==============================] - 0s 12ms/step - loss: 0.0681 - mse: 0.0102 - mae: 0.0789 - val_loss: 0.1237 - val_mse: 0.0692 - val_mae: 0.2262 - lr: 0.0010
# Epoch 16/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0627 - mse: 0.0106 - mae: 0.0817
# Epoch 16: val_loss improved from 0.12375 to 0.11571, saving model to model\best_model.hdf5
# 21/21 [==============================] - 0s 12ms/step - loss: 0.0623 - mse: 0.0104 - mae: 0.0809 - val_loss: 0.1157 - val_mse: 0.0667 - val_mae: 0.2217 - lr: 0.0010
# Epoch 17/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0566 - mse: 0.0098 - mae: 0.0772
# Epoch 17: val_loss improved from 0.11571 to 0.10989, saving model to model\best_model.hdf5
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0564 - mse: 0.0097 - mae: 0.0771 - val_loss: 0.1099 - val_mse: 0.0658 - val_mae: 0.2204 - lr: 0.0010
# Epoch 18/500
# 18/21 [========================>.....] - ETA: 0s - loss: 0.0516 - mse: 0.0094 - mae: 0.0765
# Epoch 18: val_loss improved from 0.10989 to 0.10487, saving model to model\best_model.hdf5
# 21/21 [==============================] - 0s 13ms/step - loss: 0.0514 - mse: 0.0094 - mae: 0.0761 - val_loss: 0.1049 - val_mse: 0.0652 - val_mae: 0.2189 - lr: 0.0010
# Epoch 19/500
# 21/21 [==============================] - ETA: 0s - loss: 0.0468 - mse: 0.0090 - mae: 0.0746
# Epoch 19: val_loss improved from 0.10487 to 0.10066, saving model to model\best_model.hdf5
# 21/21 [==============================] - 0s 14ms/step - loss: 0.0468 - mse: 0.0090 - mae: 0.0746 - val_loss: 0.1007 - val_mse: 0.0649 - val_mae: 0.2182 - lr: 0.0010
# Epoch 20/500
# 17/21 [=======================>......] - ETA: 0s - loss: 0.0439 - mse: 0.0095 - mae: 0.0748
# Epoch 20: val_loss improved from 0.10066 to 0.09713, saving model to model\best_model.hdf5
# 21/21 [==============================] - 0s 14ms/step - loss: 0.0435 - mse: 0.0094 - mae: 0.0748 - val_loss: 0.0971 - val_mse: 0.0648 - val_mae: 0.2175 - lr: 0.0010
# Epoch 21/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0404 - mse: 0.0094 - mae: 0.0747
# Epoch 21: val_loss improved from 0.09713 to 0.09329, saving model to model\best_model.hdf5
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0403 - mse: 0.0094 - mae: 0.0749 - val_loss: 0.0933 - val_mse: 0.0640 - val_mae: 0.2157 - lr: 0.0010
# Epoch 22/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0375 - mse: 0.0093 - mae: 0.0752
# Epoch 22: val_loss improved from 0.09329 to 0.08554, saving model to model\best_model.hdf5
# 21/21 [==============================] - 0s 12ms/step - loss: 0.0375 - mse: 0.0093 - mae: 0.0749 - val_loss: 0.0855 - val_mse: 0.0587 - val_mae: 0.2054 - lr: 0.0010
# Epoch 23/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0349 - mse: 0.0092 - mae: 0.0760
# Epoch 23: val_loss improved from 0.08554 to 0.08089, saving model to model\best_model.hdf5
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0351 - mse: 0.0094 - mae: 0.0763 - val_loss: 0.0809 - val_mse: 0.0565 - val_mae: 0.2008 - lr: 0.0010
# Epoch 24/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0339 - mse: 0.0104 - mae: 0.0758
# Epoch 24: val_loss improved from 0.08089 to 0.07756, saving model to model\best_model.hdf5
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0338 - mse: 0.0103 - mae: 0.0754 - val_loss: 0.0776 - val_mse: 0.0551 - val_mae: 0.1969 - lr: 0.0010
# Epoch 25/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0306 - mse: 0.0090 - mae: 0.0738
# Epoch 25: val_loss improved from 0.07756 to 0.07307, saving model to model\best_model.hdf5
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0305 - mse: 0.0089 - mae: 0.0733 - val_loss: 0.0731 - val_mse: 0.0525 - val_mae: 0.1912 - lr: 0.0010
# Epoch 26/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0287 - mse: 0.0088 - mae: 0.0716
# Epoch 26: val_loss improved from 0.07307 to 0.06881, saving model to model\best_model.hdf5
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0287 - mse: 0.0090 - mae: 0.0721 - val_loss: 0.0688 - val_mse: 0.0499 - val_mae: 0.1865 - lr: 0.0010
# Epoch 27/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0282 - mse: 0.0100 - mae: 0.0742
# Epoch 27: val_loss did not improve from 0.06881
# 21/21 [==============================] - 0s 10ms/step - loss: 0.0281 - mse: 0.0100 - mae: 0.0745 - val_loss: 0.0701 - val_mse: 0.0528 - val_mae: 0.1912 - lr: 0.0010
# Epoch 28/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0261 - mse: 0.0093 - mae: 0.0737
# Epoch 28: val_loss improved from 0.06881 to 0.06129, saving model to model\best_model.hdf5
# 21/21 [==============================] - 0s 12ms/step - loss: 0.0259 - mse: 0.0092 - mae: 0.0735 - val_loss: 0.0613 - val_mse: 0.0452 - val_mae: 0.1746 - lr: 0.0010
# Epoch 29/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0241 - mse: 0.0086 - mae: 0.0696
# Epoch 29: val_loss did not improve from 0.06129
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0240 - mse: 0.0085 - mae: 0.0698 - val_loss: 0.0613 - val_mse: 0.0466 - val_mae: 0.1768 - lr: 0.0010
# Epoch 30/500
# 18/21 [========================>.....] - ETA: 0s - loss: 0.0235 - mse: 0.0091 - mae: 0.0728
# Epoch 30: val_loss improved from 0.06129 to 0.04772, saving model to model\best_model.hdf5
# 21/21 [==============================] - 0s 12ms/step - loss: 0.0235 - mse: 0.0091 - mae: 0.0724 - val_loss: 0.0477 - val_mse: 0.0338 - val_mae: 0.1491 - lr: 0.0010
# Epoch 31/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0230 - mse: 0.0096 - mae: 0.0718
# Epoch 31: val_loss improved from 0.04772 to 0.04627, saving model to model\best_model.hdf5
# 21/21 [==============================] - 0s 12ms/step - loss: 0.0229 - mse: 0.0095 - mae: 0.0714 - val_loss: 0.0463 - val_mse: 0.0334 - val_mae: 0.1471 - lr: 0.0010
# Epoch 32/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0218 - mse: 0.0093 - mae: 0.0723
# Epoch 32: val_loss improved from 0.04627 to 0.04462, saving model to model\best_model.hdf5
# 21/21 [==============================] - 0s 12ms/step - loss: 0.0217 - mse: 0.0092 - mae: 0.0722 - val_loss: 0.0446 - val_mse: 0.0327 - val_mae: 0.1449 - lr: 0.0010
# Epoch 33/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0207 - mse: 0.0090 - mae: 0.0720
# Epoch 33: val_loss improved from 0.04462 to 0.03551, saving model to model\best_model.hdf5
# 21/21 [==============================] - 0s 12ms/step - loss: 0.0210 - mse: 0.0093 - mae: 0.0720 - val_loss: 0.0355 - val_mse: 0.0242 - val_mae: 0.1240 - lr: 0.0010
# Epoch 34/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0199 - mse: 0.0089 - mae: 0.0711
# Epoch 34: val_loss improved from 0.03551 to 0.03459, saving model to model\best_model.hdf5
# 21/21 [==============================] - 0s 12ms/step - loss: 0.0199 - mse: 0.0089 - mae: 0.0710 - val_loss: 0.0346 - val_mse: 0.0240 - val_mae: 0.1224 - lr: 0.0010
# Epoch 35/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0189 - mse: 0.0086 - mae: 0.0695
# Epoch 35: val_loss improved from 0.03459 to 0.02597, saving model to model\best_model.hdf5
# 21/21 [==============================] - 0s 12ms/step - loss: 0.0191 - mse: 0.0088 - mae: 0.0700 - val_loss: 0.0260 - val_mse: 0.0159 - val_mae: 0.1005 - lr: 0.0010
# Epoch 36/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0182 - mse: 0.0084 - mae: 0.0685
# Epoch 36: val_loss did not improve from 0.02597
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0182 - mse: 0.0085 - mae: 0.0686 - val_loss: 0.0274 - val_mse: 0.0180 - val_mae: 0.1060 - lr: 0.0010
# Epoch 37/500
# 21/21 [==============================] - ETA: 0s - loss: 0.0179 - mse: 0.0086 - mae: 0.0686
# Epoch 37: val_loss did not improve from 0.02597
# 21/21 [==============================] - 0s 12ms/step - loss: 0.0179 - mse: 0.0086 - mae: 0.0686 - val_loss: 0.0262 - val_mse: 0.0173 - val_mae: 0.1042 - lr: 0.0010
# Epoch 38/500
# 18/21 [========================>.....] - ETA: 0s - loss: 0.0177 - mse: 0.0089 - mae: 0.0705
# Epoch 38: val_loss improved from 0.02597 to 0.01737, saving model to model\best_model.hdf5
# 21/21 [==============================] - 0s 12ms/step - loss: 0.0174 - mse: 0.0086 - mae: 0.0694 - val_loss: 0.0174 - val_mse: 0.0087 - val_mae: 0.0753 - lr: 0.0010
# Epoch 39/500
# 17/21 [=======================>......] - ETA: 0s - loss: 0.0171 - mse: 0.0086 - mae: 0.0677
# Epoch 39: val_loss did not improve from 0.01737
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0170 - mse: 0.0086 - mae: 0.0678 - val_loss: 0.0187 - val_mse: 0.0105 - val_mae: 0.0813 - lr: 0.0010
# Epoch 40/500
# 18/21 [========================>.....] - ETA: 0s - loss: 0.0163 - mse: 0.0083 - mae: 0.0687
# Epoch 40: val_loss improved from 0.01737 to 0.01484, saving model to model\best_model.hdf5
# 21/21 [==============================] - 0s 13ms/step - loss: 0.0164 - mse: 0.0083 - mae: 0.0685 - val_loss: 0.0148 - val_mse: 0.0069 - val_mae: 0.0687 - lr: 0.0010
# Epoch 41/500
# 17/21 [=======================>......] - ETA: 0s - loss: 0.0167 - mse: 0.0089 - mae: 0.0686
# Epoch 41: val_loss did not improve from 0.01484
# 21/21 [==============================] - 0s 12ms/step - loss: 0.0163 - mse: 0.0085 - mae: 0.0675 - val_loss: 0.0150 - val_mse: 0.0075 - val_mae: 0.0708 - lr: 0.0010
# Epoch 42/500
# 18/21 [========================>.....] - ETA: 0s - loss: 0.0157 - mse: 0.0083 - mae: 0.0675
# Epoch 42: val_loss improved from 0.01484 to 0.01421, saving model to model\best_model.hdf5
# 21/21 [==============================] - 0s 12ms/step - loss: 0.0158 - mse: 0.0084 - mae: 0.0676 - val_loss: 0.0142 - val_mse: 0.0069 - val_mae: 0.0694 - lr: 0.0010
# Epoch 43/500
# 17/21 [=======================>......] - ETA: 0s - loss: 0.0154 - mse: 0.0083 - mae: 0.0668
# Epoch 43: val_loss did not improve from 0.01421
# 21/21 [==============================] - 0s 12ms/step - loss: 0.0155 - mse: 0.0084 - mae: 0.0676 - val_loss: 0.0143 - val_mse: 0.0073 - val_mae: 0.0709 - lr: 0.0010
# Epoch 44/500
# 21/21 [==============================] - ETA: 0s - loss: 0.0156 - mse: 0.0087 - mae: 0.0680
# Epoch 44: val_loss improved from 0.01421 to 0.01339, saving model to model\best_model.hdf5
# 21/21 [==============================] - 0s 13ms/step - loss: 0.0156 - mse: 0.0087 - mae: 0.0680 - val_loss: 0.0134 - val_mse: 0.0066 - val_mae: 0.0679 - lr: 0.0010
# Epoch 45/500
# 16/21 [=====================>........] - ETA: 0s - loss: 0.0157 - mse: 0.0090 - mae: 0.0689
# Epoch 45: val_loss improved from 0.01339 to 0.01297, saving model to model\best_model.hdf5
# 21/21 [==============================] - 0s 13ms/step - loss: 0.0153 - mse: 0.0086 - mae: 0.0677 - val_loss: 0.0130 - val_mse: 0.0065 - val_mae: 0.0671 - lr: 0.0010
# Epoch 46/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0148 - mse: 0.0083 - mae: 0.0666
# Epoch 46: val_loss improved from 0.01297 to 0.01295, saving model to model\best_model.hdf5
# 21/21 [==============================] - 0s 12ms/step - loss: 0.0150 - mse: 0.0085 - mae: 0.0670 - val_loss: 0.0129 - val_mse: 0.0065 - val_mae: 0.0675 - lr: 0.0010
# Epoch 47/500
# 17/21 [=======================>......] - ETA: 0s - loss: 0.0150 - mse: 0.0086 - mae: 0.0674
# Epoch 47: val_loss did not improve from 0.01295
# 21/21 [==============================] - 0s 12ms/step - loss: 0.0151 - mse: 0.0087 - mae: 0.0674 - val_loss: 0.0130 - val_mse: 0.0069 - val_mae: 0.0679 - lr: 0.0010
# Epoch 48/500
# 16/21 [=====================>........] - ETA: 0s - loss: 0.0162 - mse: 0.0101 - mae: 0.0714
# Epoch 48: val_loss improved from 0.01295 to 0.01228, saving model to model\best_model.hdf5
# 21/21 [==============================] - 0s 13ms/step - loss: 0.0160 - mse: 0.0099 - mae: 0.0718 - val_loss: 0.0123 - val_mse: 0.0064 - val_mae: 0.0644 - lr: 0.0010
# Epoch 49/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0146 - mse: 0.0086 - mae: 0.0665
# Epoch 49: val_loss did not improve from 0.01228
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0146 - mse: 0.0086 - mae: 0.0670 - val_loss: 0.0129 - val_mse: 0.0073 - val_mae: 0.0670 - lr: 0.0010
# Epoch 50/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0142 - mse: 0.0084 - mae: 0.0672
# Epoch 50: val_loss did not improve from 0.01228
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0143 - mse: 0.0085 - mae: 0.0673 - val_loss: 0.0129 - val_mse: 0.0071 - val_mae: 0.0682 - lr: 0.0010
# Epoch 51/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0140 - mse: 0.0083 - mae: 0.0662
# Epoch 51: val_loss did not improve from 0.01228
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0141 - mse: 0.0085 - mae: 0.0664 - val_loss: 0.0145 - val_mse: 0.0088 - val_mae: 0.0757 - lr: 0.0010
# Epoch 52/500
# 18/21 [========================>.....] - ETA: 0s - loss: 0.0149 - mse: 0.0093 - mae: 0.0680
# Epoch 52: val_loss improved from 0.01228 to 0.01216, saving model to model\best_model.hdf5
# 21/21 [==============================] - 0s 12ms/step - loss: 0.0148 - mse: 0.0092 - mae: 0.0678 - val_loss: 0.0122 - val_mse: 0.0067 - val_mae: 0.0679 - lr: 0.0010
# Epoch 53/500
# 18/21 [========================>.....] - ETA: 0s - loss: 0.0138 - mse: 0.0084 - mae: 0.0664
# Epoch 53: val_loss improved from 0.01216 to 0.01119, saving model to model\best_model.hdf5
# 21/21 [==============================] - 0s 13ms/step - loss: 0.0142 - mse: 0.0088 - mae: 0.0676 - val_loss: 0.0112 - val_mse: 0.0059 - val_mae: 0.0630 - lr: 0.0010
# Epoch 54/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0143 - mse: 0.0089 - mae: 0.0674
# Epoch 54: val_loss did not improve from 0.01119
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0143 - mse: 0.0090 - mae: 0.0672 - val_loss: 0.0139 - val_mse: 0.0085 - val_mae: 0.0746 - lr: 0.0010
# Epoch 55/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0138 - mse: 0.0086 - mae: 0.0671
# Epoch 55: val_loss did not improve from 0.01119
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0136 - mse: 0.0085 - mae: 0.0665 - val_loss: 0.0124 - val_mse: 0.0073 - val_mae: 0.0704 - lr: 0.0010
# Epoch 56/500
# 18/21 [========================>.....] - ETA: 0s - loss: 0.0136 - mse: 0.0085 - mae: 0.0658
# Epoch 56: val_loss did not improve from 0.01119
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0137 - mse: 0.0086 - mae: 0.0664 - val_loss: 0.0118 - val_mse: 0.0068 - val_mae: 0.0689 - lr: 0.0010
# Epoch 57/500
# 21/21 [==============================] - ETA: 0s - loss: 0.0136 - mse: 0.0085 - mae: 0.0669
# Epoch 57: val_loss did not improve from 0.01119
#
# Epoch 57: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 21/21 [==============================] - 0s 13ms/step - loss: 0.0136 - mse: 0.0085 - mae: 0.0669 - val_loss: 0.0154 - val_mse: 0.0104 - val_mae: 0.0820 - lr: 0.0010
# Epoch 58/500
# 21/21 [==============================] - ETA: 0s - loss: 0.0137 - mse: 0.0087 - mae: 0.0660
# Epoch 58: val_loss did not improve from 0.01119
# 21/21 [==============================] - 0s 13ms/step - loss: 0.0137 - mse: 0.0087 - mae: 0.0660 - val_loss: 0.0129 - val_mse: 0.0080 - val_mae: 0.0727 - lr: 5.0000e-04
# Epoch 59/500
# 20/21 [===========================>..] - ETA: 0s - loss: 0.0138 - mse: 0.0089 - mae: 0.0670
# Epoch 59: val_loss did not improve from 0.01119
# 21/21 [==============================] - 0s 14ms/step - loss: 0.0137 - mse: 0.0088 - mae: 0.0667 - val_loss: 0.0128 - val_mse: 0.0079 - val_mae: 0.0719 - lr: 5.0000e-04
# Epoch 60/500
# 21/21 [==============================] - ETA: 0s - loss: 0.0135 - mse: 0.0087 - mae: 0.0670
# Epoch 60: val_loss did not improve from 0.01119
# 21/21 [==============================] - 0s 13ms/step - loss: 0.0135 - mse: 0.0087 - mae: 0.0670 - val_loss: 0.0134 - val_mse: 0.0085 - val_mae: 0.0743 - lr: 5.0000e-04
# Epoch 61/500
# 21/21 [==============================] - ETA: 0s - loss: 0.0137 - mse: 0.0088 - mae: 0.0663
# Epoch 61: val_loss improved from 0.01119 to 0.01083, saving model to model\best_model.hdf5
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0137 - mse: 0.0088 - mae: 0.0663 - val_loss: 0.0108 - val_mse: 0.0061 - val_mae: 0.0643 - lr: 5.0000e-04
# Epoch 62/500
# 21/21 [==============================] - ETA: 0s - loss: 0.0135 - mse: 0.0086 - mae: 0.0652
# Epoch 62: val_loss improved from 0.01083 to 0.01053, saving model to model\best_model.hdf5
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0135 - mse: 0.0086 - mae: 0.0652 - val_loss: 0.0105 - val_mse: 0.0059 - val_mae: 0.0622 - lr: 5.0000e-04
# Epoch 63/500
# 21/21 [==============================] - ETA: 0s - loss: 0.0133 - mse: 0.0086 - mae: 0.0675
# Epoch 63: val_loss did not improve from 0.01053
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0133 - mse: 0.0086 - mae: 0.0675 - val_loss: 0.0148 - val_mse: 0.0100 - val_mae: 0.0786 - lr: 5.0000e-04
# Epoch 64/500
# 21/21 [==============================] - ETA: 0s - loss: 0.0134 - mse: 0.0087 - mae: 0.0663
# Epoch 64: val_loss did not improve from 0.01053
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0134 - mse: 0.0087 - mae: 0.0663 - val_loss: 0.0106 - val_mse: 0.0060 - val_mae: 0.0631 - lr: 5.0000e-04
# Epoch 65/500
# 20/21 [===========================>..] - ETA: 0s - loss: 0.0128 - mse: 0.0082 - mae: 0.0653
# Epoch 65: val_loss did not improve from 0.01053
# 21/21 [==============================] - 0s 14ms/step - loss: 0.0128 - mse: 0.0081 - mae: 0.0652 - val_loss: 0.0126 - val_mse: 0.0080 - val_mae: 0.0721 - lr: 5.0000e-04
# Epoch 66/500
# 21/21 [==============================] - ETA: 0s - loss: 0.0131 - mse: 0.0085 - mae: 0.0655
# Epoch 66: val_loss did not improve from 0.01053
#
# Epoch 66: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0131 - mse: 0.0085 - mae: 0.0655 - val_loss: 0.0126 - val_mse: 0.0079 - val_mae: 0.0722 - lr: 5.0000e-04
# Epoch 67/500
# 21/21 [==============================] - ETA: 0s - loss: 0.0130 - mse: 0.0084 - mae: 0.0653
# Epoch 67: val_loss did not improve from 0.01053
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0130 - mse: 0.0084 - mae: 0.0653 - val_loss: 0.0116 - val_mse: 0.0070 - val_mae: 0.0676 - lr: 2.5000e-04
# Epoch 68/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0130 - mse: 0.0084 - mae: 0.0651
# Epoch 68: val_loss did not improve from 0.01053
# 21/21 [==============================] - 0s 14ms/step - loss: 0.0130 - mse: 0.0084 - mae: 0.0654 - val_loss: 0.0119 - val_mse: 0.0073 - val_mae: 0.0690 - lr: 2.5000e-04
# Epoch 69/500
# 18/21 [========================>.....] - ETA: 0s - loss: 0.0129 - mse: 0.0083 - mae: 0.0651
# Epoch 69: val_loss did not improve from 0.01053
# 21/21 [==============================] - 0s 14ms/step - loss: 0.0131 - mse: 0.0085 - mae: 0.0656 - val_loss: 0.0108 - val_mse: 0.0062 - val_mae: 0.0641 - lr: 2.5000e-04
# Epoch 70/500
# 16/21 [=====================>........] - ETA: 0s - loss: 0.0126 - mse: 0.0081 - mae: 0.0641
# Epoch 70: val_loss did not improve from 0.01053
#
# Epoch 70: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 21/21 [==============================] - 0s 12ms/step - loss: 0.0129 - mse: 0.0084 - mae: 0.0650 - val_loss: 0.0109 - val_mse: 0.0064 - val_mae: 0.0647 - lr: 2.5000e-04
# Epoch 71/500
# 18/21 [========================>.....] - ETA: 0s - loss: 0.0129 - mse: 0.0083 - mae: 0.0655
# Epoch 71: val_loss improved from 0.01053 to 0.01049, saving model to model\best_model.hdf5
# 21/21 [==============================] - 0s 13ms/step - loss: 0.0129 - mse: 0.0083 - mae: 0.0656 - val_loss: 0.0105 - val_mse: 0.0060 - val_mae: 0.0625 - lr: 1.2500e-04
# Epoch 72/500
# 21/21 [==============================] - ETA: 0s - loss: 0.0126 - mse: 0.0081 - mae: 0.0645
# Epoch 72: val_loss did not improve from 0.01049
# 21/21 [==============================] - 0s 10ms/step - loss: 0.0126 - mse: 0.0081 - mae: 0.0645 - val_loss: 0.0106 - val_mse: 0.0060 - val_mae: 0.0625 - lr: 1.2500e-04
# Epoch 73/500
# 21/21 [==============================] - ETA: 0s - loss: 0.0129 - mse: 0.0083 - mae: 0.0650
# Epoch 73: val_loss did not improve from 0.01049
# 21/21 [==============================] - 0s 9ms/step - loss: 0.0129 - mse: 0.0083 - mae: 0.0650 - val_loss: 0.0107 - val_mse: 0.0061 - val_mae: 0.0627 - lr: 1.2500e-04
# Epoch 74/500
# 15/21 [====================>.........] - ETA: 0s - loss: 0.0129 - mse: 0.0084 - mae: 0.0650
# Epoch 74: val_loss improved from 0.01049 to 0.01024, saving model to model\best_model.hdf5
# 21/21 [==============================] - 0s 10ms/step - loss: 0.0133 - mse: 0.0088 - mae: 0.0665 - val_loss: 0.0102 - val_mse: 0.0057 - val_mae: 0.0604 - lr: 1.2500e-04
# Epoch 75/500
# 16/21 [=====================>........] - ETA: 0s - loss: 0.0128 - mse: 0.0082 - mae: 0.0637
# Epoch 75: val_loss did not improve from 0.01024
# 21/21 [==============================] - 0s 9ms/step - loss: 0.0130 - mse: 0.0084 - mae: 0.0642 - val_loss: 0.0103 - val_mse: 0.0058 - val_mae: 0.0605 - lr: 1.2500e-04
# Epoch 76/500
# 15/21 [====================>.........] - ETA: 0s - loss: 0.0135 - mse: 0.0089 - mae: 0.0659
# Epoch 76: val_loss improved from 0.01024 to 0.00979, saving model to model\best_model.hdf5
# 21/21 [==============================] - 0s 10ms/step - loss: 0.0132 - mse: 0.0087 - mae: 0.0652 - val_loss: 0.0098 - val_mse: 0.0053 - val_mae: 0.0577 - lr: 1.2500e-04
# Epoch 77/500
# 21/21 [==============================] - ETA: 0s - loss: 0.0129 - mse: 0.0084 - mae: 0.0656
# Epoch 77: val_loss did not improve from 0.00979
# 21/21 [==============================] - 0s 10ms/step - loss: 0.0129 - mse: 0.0084 - mae: 0.0656 - val_loss: 0.0099 - val_mse: 0.0054 - val_mae: 0.0582 - lr: 1.2500e-04
# Epoch 78/500
# 16/21 [=====================>........] - ETA: 0s - loss: 0.0124 - mse: 0.0080 - mae: 0.0649
# Epoch 78: val_loss did not improve from 0.00979
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0127 - mse: 0.0083 - mae: 0.0656 - val_loss: 0.0100 - val_mse: 0.0055 - val_mae: 0.0591 - lr: 1.2500e-04
# Epoch 79/500
# 15/21 [====================>.........] - ETA: 0s - loss: 0.0131 - mse: 0.0086 - mae: 0.0659
# Epoch 79: val_loss did not improve from 0.00979
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0134 - mse: 0.0089 - mae: 0.0665 - val_loss: 0.0098 - val_mse: 0.0054 - val_mae: 0.0583 - lr: 1.2500e-04
# Epoch 80/500
# 16/21 [=====================>........] - ETA: 0s - loss: 0.0129 - mse: 0.0084 - mae: 0.0647
# Epoch 80: val_loss did not improve from 0.00979
#
# Epoch 80: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 21/21 [==============================] - 0s 9ms/step - loss: 0.0134 - mse: 0.0089 - mae: 0.0660 - val_loss: 0.0102 - val_mse: 0.0057 - val_mae: 0.0599 - lr: 1.2500e-04
# Epoch 81/500
# 15/21 [====================>.........] - ETA: 0s - loss: 0.0125 - mse: 0.0080 - mae: 0.0638
# Epoch 81: val_loss did not improve from 0.00979
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0126 - mse: 0.0081 - mae: 0.0641 - val_loss: 0.0098 - val_mse: 0.0053 - val_mae: 0.0579 - lr: 6.2500e-05
# Epoch 82/500
# 16/21 [=====================>........] - ETA: 0s - loss: 0.0126 - mse: 0.0081 - mae: 0.0643
# Epoch 82: val_loss improved from 0.00979 to 0.00979, saving model to model\best_model.hdf5
# 21/21 [==============================] - 0s 10ms/step - loss: 0.0129 - mse: 0.0085 - mae: 0.0652 - val_loss: 0.0098 - val_mse: 0.0053 - val_mae: 0.0578 - lr: 6.2500e-05
# Epoch 83/500
# 20/21 [===========================>..] - ETA: 0s - loss: 0.0129 - mse: 0.0084 - mae: 0.0660
# Epoch 83: val_loss improved from 0.00979 to 0.00968, saving model to model\best_model.hdf5
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0129 - mse: 0.0084 - mae: 0.0661 - val_loss: 0.0097 - val_mse: 0.0052 - val_mae: 0.0571 - lr: 6.2500e-05
# Epoch 84/500
# 21/21 [==============================] - ETA: 0s - loss: 0.0129 - mse: 0.0084 - mae: 0.0649
# Epoch 84: val_loss improved from 0.00968 to 0.00968, saving model to model\best_model.hdf5
# 21/21 [==============================] - 0s 10ms/step - loss: 0.0129 - mse: 0.0084 - mae: 0.0649 - val_loss: 0.0097 - val_mse: 0.0052 - val_mae: 0.0570 - lr: 6.2500e-05
# Epoch 85/500
# 15/21 [====================>.........] - ETA: 0s - loss: 0.0126 - mse: 0.0081 - mae: 0.0638
# Epoch 85: val_loss did not improve from 0.00968
# 21/21 [==============================] - 0s 9ms/step - loss: 0.0125 - mse: 0.0081 - mae: 0.0636 - val_loss: 0.0097 - val_mse: 0.0053 - val_mae: 0.0572 - lr: 6.2500e-05
# Epoch 86/500
# 20/21 [===========================>..] - ETA: 0s - loss: 0.0129 - mse: 0.0085 - mae: 0.0659
# Epoch 86: val_loss improved from 0.00968 to 0.00965, saving model to model\best_model.hdf5
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0130 - mse: 0.0085 - mae: 0.0661 - val_loss: 0.0096 - val_mse: 0.0052 - val_mae: 0.0569 - lr: 6.2500e-05
# Epoch 87/500
# 15/21 [====================>.........] - ETA: 0s - loss: 0.0128 - mse: 0.0083 - mae: 0.0639
# Epoch 87: val_loss did not improve from 0.00965
#
# Epoch 87: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 21/21 [==============================] - 0s 9ms/step - loss: 0.0126 - mse: 0.0081 - mae: 0.0634 - val_loss: 0.0098 - val_mse: 0.0054 - val_mae: 0.0578 - lr: 6.2500e-05
# Epoch 88/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0126 - mse: 0.0081 - mae: 0.0635
# Epoch 88: val_loss did not improve from 0.00965
# 21/21 [==============================] - 0s 10ms/step - loss: 0.0124 - mse: 0.0080 - mae: 0.0632 - val_loss: 0.0099 - val_mse: 0.0054 - val_mae: 0.0581 - lr: 3.1250e-05
# Epoch 89/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0128 - mse: 0.0083 - mae: 0.0645
# Epoch 89: val_loss improved from 0.00965 to 0.00957, saving model to model\best_model.hdf5
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0126 - mse: 0.0082 - mae: 0.0641 - val_loss: 0.0096 - val_mse: 0.0051 - val_mae: 0.0562 - lr: 3.1250e-05
# Epoch 90/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0126 - mse: 0.0081 - mae: 0.0645
# Epoch 90: val_loss did not improve from 0.00957
# 21/21 [==============================] - 0s 10ms/step - loss: 0.0128 - mse: 0.0084 - mae: 0.0656 - val_loss: 0.0096 - val_mse: 0.0052 - val_mae: 0.0567 - lr: 3.1250e-05
# Epoch 91/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0129 - mse: 0.0084 - mae: 0.0651
# Epoch 91: val_loss improved from 0.00957 to 0.00957, saving model to model\best_model.hdf5
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0129 - mse: 0.0085 - mae: 0.0655 - val_loss: 0.0096 - val_mse: 0.0051 - val_mae: 0.0562 - lr: 3.1250e-05
# Epoch 92/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0126 - mse: 0.0082 - mae: 0.0650
# Epoch 92: val_loss did not improve from 0.00957
# 21/21 [==============================] - 0s 10ms/step - loss: 0.0126 - mse: 0.0082 - mae: 0.0648 - val_loss: 0.0096 - val_mse: 0.0052 - val_mae: 0.0563 - lr: 3.1250e-05
# Epoch 93/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0131 - mse: 0.0087 - mae: 0.0663
# Epoch 93: val_loss improved from 0.00957 to 0.00956, saving model to model\best_model.hdf5
#
# Epoch 93: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 21/21 [==============================] - 0s 12ms/step - loss: 0.0133 - mse: 0.0089 - mae: 0.0670 - val_loss: 0.0096 - val_mse: 0.0051 - val_mae: 0.0562 - lr: 3.1250e-05
# Epoch 94/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0124 - mse: 0.0080 - mae: 0.0640
# Epoch 94: val_loss did not improve from 0.00956
# 21/21 [==============================] - 0s 10ms/step - loss: 0.0125 - mse: 0.0081 - mae: 0.0641 - val_loss: 0.0096 - val_mse: 0.0051 - val_mae: 0.0562 - lr: 1.5625e-05
# Epoch 95/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0128 - mse: 0.0084 - mae: 0.0647
# Epoch 95: val_loss improved from 0.00956 to 0.00956, saving model to model\best_model.hdf5
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0128 - mse: 0.0084 - mae: 0.0647 - val_loss: 0.0096 - val_mse: 0.0051 - val_mae: 0.0561 - lr: 1.5625e-05
# Epoch 96/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0135 - mse: 0.0091 - mae: 0.0678
# Epoch 96: val_loss did not improve from 0.00956
# 21/21 [==============================] - 0s 10ms/step - loss: 0.0136 - mse: 0.0091 - mae: 0.0677 - val_loss: 0.0096 - val_mse: 0.0052 - val_mae: 0.0564 - lr: 1.5625e-05
# Epoch 97/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0128 - mse: 0.0084 - mae: 0.0654
# Epoch 97: val_loss improved from 0.00956 to 0.00951, saving model to model\best_model.hdf5
#
# Epoch 97: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 21/21 [==============================] - 0s 12ms/step - loss: 0.0127 - mse: 0.0083 - mae: 0.0652 - val_loss: 0.0095 - val_mse: 0.0051 - val_mae: 0.0558 - lr: 1.5625e-05
# Epoch 98/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0127 - mse: 0.0083 - mae: 0.0646
# Epoch 98: val_loss did not improve from 0.00951
# 21/21 [==============================] - 0s 10ms/step - loss: 0.0126 - mse: 0.0082 - mae: 0.0642 - val_loss: 0.0095 - val_mse: 0.0051 - val_mae: 0.0558 - lr: 7.8125e-06
# Epoch 99/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0129 - mse: 0.0085 - mae: 0.0653
# Epoch 99: val_loss did not improve from 0.00951
# 21/21 [==============================] - 0s 10ms/step - loss: 0.0128 - mse: 0.0084 - mae: 0.0650 - val_loss: 0.0095 - val_mse: 0.0051 - val_mae: 0.0559 - lr: 7.8125e-06
# Epoch 100/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0128 - mse: 0.0084 - mae: 0.0653
# Epoch 100: val_loss improved from 0.00951 to 0.00950, saving model to model\best_model.hdf5
# 21/21 [==============================] - 0s 13ms/step - loss: 0.0128 - mse: 0.0084 - mae: 0.0654 - val_loss: 0.0095 - val_mse: 0.0051 - val_mae: 0.0557 - lr: 7.8125e-06
# Epoch 101/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0127 - mse: 0.0083 - mae: 0.0641
# Epoch 101: val_loss did not improve from 0.00950
#
# Epoch 101: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 21/21 [==============================] - 0s 12ms/step - loss: 0.0125 - mse: 0.0081 - mae: 0.0638 - val_loss: 0.0095 - val_mse: 0.0051 - val_mae: 0.0558 - lr: 7.8125e-06
# Epoch 102/500
# 20/21 [===========================>..] - ETA: 0s - loss: 0.0125 - mse: 0.0081 - mae: 0.0635
# Epoch 102: val_loss did not improve from 0.00950
# 21/21 [==============================] - 0s 13ms/step - loss: 0.0126 - mse: 0.0082 - mae: 0.0638 - val_loss: 0.0095 - val_mse: 0.0051 - val_mae: 0.0558 - lr: 3.9063e-06
# Epoch 103/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0127 - mse: 0.0082 - mae: 0.0645
# Epoch 103: val_loss improved from 0.00950 to 0.00949, saving model to model\best_model.hdf5
# 21/21 [==============================] - 0s 12ms/step - loss: 0.0126 - mse: 0.0082 - mae: 0.0645 - val_loss: 0.0095 - val_mse: 0.0051 - val_mae: 0.0556 - lr: 3.9063e-06
# Epoch 104/500
# 18/21 [========================>.....] - ETA: 0s - loss: 0.0135 - mse: 0.0091 - mae: 0.0674
# Epoch 104: val_loss did not improve from 0.00949
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0134 - mse: 0.0090 - mae: 0.0671 - val_loss: 0.0095 - val_mse: 0.0051 - val_mae: 0.0556 - lr: 3.9063e-06
# Epoch 105/500
# 17/21 [=======================>......] - ETA: 0s - loss: 0.0125 - mse: 0.0081 - mae: 0.0640
# Epoch 105: val_loss did not improve from 0.00949
#
# Epoch 105: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 21/21 [==============================] - 0s 13ms/step - loss: 0.0127 - mse: 0.0083 - mae: 0.0650 - val_loss: 0.0095 - val_mse: 0.0051 - val_mae: 0.0558 - lr: 3.9063e-06
# Epoch 106/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0130 - mse: 0.0086 - mae: 0.0659
# Epoch 106: val_loss did not improve from 0.00949
# 21/21 [==============================] - 0s 10ms/step - loss: 0.0129 - mse: 0.0085 - mae: 0.0654 - val_loss: 0.0095 - val_mse: 0.0051 - val_mae: 0.0556 - lr: 1.9531e-06
# Epoch 107/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0124 - mse: 0.0080 - mae: 0.0640
# Epoch 107: val_loss improved from 0.00949 to 0.00949, saving model to model\best_model.hdf5
# 21/21 [==============================] - 0s 12ms/step - loss: 0.0125 - mse: 0.0081 - mae: 0.0641 - val_loss: 0.0095 - val_mse: 0.0051 - val_mae: 0.0556 - lr: 1.9531e-06
# Epoch 108/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0128 - mse: 0.0084 - mae: 0.0651
# Epoch 108: val_loss did not improve from 0.00949
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0127 - mse: 0.0082 - mae: 0.0647 - val_loss: 0.0095 - val_mse: 0.0051 - val_mae: 0.0556 - lr: 1.9531e-06
# Epoch 109/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0129 - mse: 0.0085 - mae: 0.0656
# Epoch 109: val_loss did not improve from 0.00949
#
# Epoch 109: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0130 - mse: 0.0086 - mae: 0.0658 - val_loss: 0.0095 - val_mse: 0.0051 - val_mae: 0.0557 - lr: 1.9531e-06
# Epoch 110/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0126 - mse: 0.0082 - mae: 0.0645
# Epoch 110: val_loss improved from 0.00949 to 0.00948, saving model to model\best_model.hdf5
# 21/21 [==============================] - 0s 12ms/step - loss: 0.0129 - mse: 0.0085 - mae: 0.0653 - val_loss: 0.0095 - val_mse: 0.0051 - val_mae: 0.0555 - lr: 9.7656e-07
# Epoch 111/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0130 - mse: 0.0086 - mae: 0.0655
# Epoch 111: val_loss improved from 0.00948 to 0.00948, saving model to model\best_model.hdf5
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0131 - mse: 0.0087 - mae: 0.0658 - val_loss: 0.0095 - val_mse: 0.0051 - val_mae: 0.0555 - lr: 9.7656e-07
# Epoch 112/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0129 - mse: 0.0085 - mae: 0.0652
# Epoch 112: val_loss improved from 0.00948 to 0.00947, saving model to model\best_model.hdf5
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0129 - mse: 0.0084 - mae: 0.0651 - val_loss: 0.0095 - val_mse: 0.0051 - val_mae: 0.0554 - lr: 9.7656e-07
# Epoch 113/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0125 - mse: 0.0080 - mae: 0.0635
# Epoch 113: val_loss improved from 0.00947 to 0.00947, saving model to model\best_model.hdf5
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0124 - mse: 0.0080 - mae: 0.0635 - val_loss: 0.0095 - val_mse: 0.0051 - val_mae: 0.0554 - lr: 9.7656e-07
# Epoch 114/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0128 - mse: 0.0083 - mae: 0.0645
# Epoch 114: val_loss improved from 0.00947 to 0.00946, saving model to model\best_model.hdf5
# 21/21 [==============================] - 0s 12ms/step - loss: 0.0128 - mse: 0.0083 - mae: 0.0647 - val_loss: 0.0095 - val_mse: 0.0051 - val_mae: 0.0554 - lr: 9.7656e-07
# Epoch 115/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0124 - mse: 0.0080 - mae: 0.0637
# Epoch 115: val_loss did not improve from 0.00946
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0125 - mse: 0.0080 - mae: 0.0639 - val_loss: 0.0095 - val_mse: 0.0051 - val_mae: 0.0554 - lr: 9.7656e-07
# Epoch 116/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0128 - mse: 0.0084 - mae: 0.0655
# Epoch 116: val_loss improved from 0.00946 to 0.00945, saving model to model\best_model.hdf5
#
# Epoch 116: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# 21/21 [==============================] - 0s 12ms/step - loss: 0.0129 - mse: 0.0084 - mae: 0.0654 - val_loss: 0.0095 - val_mse: 0.0050 - val_mae: 0.0553 - lr: 9.7656e-07
# Epoch 117/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0125 - mse: 0.0081 - mae: 0.0641
# Epoch 117: val_loss improved from 0.00945 to 0.00945, saving model to model\best_model.hdf5
# 21/21 [==============================] - 0s 12ms/step - loss: 0.0125 - mse: 0.0081 - mae: 0.0640 - val_loss: 0.0094 - val_mse: 0.0050 - val_mae: 0.0552 - lr: 4.8828e-07
# Epoch 118/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0125 - mse: 0.0081 - mae: 0.0638
# Epoch 118: val_loss improved from 0.00945 to 0.00944, saving model to model\best_model.hdf5
# 21/21 [==============================] - 0s 12ms/step - loss: 0.0125 - mse: 0.0081 - mae: 0.0639 - val_loss: 0.0094 - val_mse: 0.0050 - val_mae: 0.0552 - lr: 4.8828e-07
# Epoch 119/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0127 - mse: 0.0083 - mae: 0.0649
# Epoch 119: val_loss did not improve from 0.00944
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0127 - mse: 0.0083 - mae: 0.0650 - val_loss: 0.0095 - val_mse: 0.0050 - val_mae: 0.0552 - lr: 4.8828e-07
# Epoch 120/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0133 - mse: 0.0089 - mae: 0.0674
# Epoch 120: val_loss did not improve from 0.00944
#
# Epoch 120: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0134 - mse: 0.0090 - mae: 0.0674 - val_loss: 0.0095 - val_mse: 0.0050 - val_mae: 0.0553 - lr: 4.8828e-07
# Epoch 121/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0133 - mse: 0.0089 - mae: 0.0668
# Epoch 121: val_loss did not improve from 0.00944
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0132 - mse: 0.0087 - mae: 0.0663 - val_loss: 0.0095 - val_mse: 0.0050 - val_mae: 0.0553 - lr: 2.4414e-07
# Epoch 122/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0128 - mse: 0.0083 - mae: 0.0649
# Epoch 122: val_loss did not improve from 0.00944
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0127 - mse: 0.0082 - mae: 0.0647 - val_loss: 0.0095 - val_mse: 0.0050 - val_mae: 0.0553 - lr: 2.4414e-07
# Epoch 123/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0128 - mse: 0.0084 - mae: 0.0652
# Epoch 123: val_loss did not improve from 0.00944
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0127 - mse: 0.0083 - mae: 0.0650 - val_loss: 0.0095 - val_mse: 0.0050 - val_mae: 0.0553 - lr: 2.4414e-07
# Epoch 124/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0130 - mse: 0.0086 - mae: 0.0653
# Epoch 124: val_loss did not improve from 0.00944
#
# Epoch 124: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0130 - mse: 0.0085 - mae: 0.0654 - val_loss: 0.0095 - val_mse: 0.0051 - val_mae: 0.0554 - lr: 2.4414e-07
# Epoch 125/500
# 17/21 [=======================>......] - ETA: 0s - loss: 0.0125 - mse: 0.0081 - mae: 0.0643
# Epoch 125: val_loss did not improve from 0.00944
# 21/21 [==============================] - 0s 12ms/step - loss: 0.0128 - mse: 0.0083 - mae: 0.0654 - val_loss: 0.0095 - val_mse: 0.0050 - val_mae: 0.0553 - lr: 1.2207e-07
# Epoch 126/500
# 16/21 [=====================>........] - ETA: 0s - loss: 0.0127 - mse: 0.0083 - mae: 0.0651
# Epoch 126: val_loss improved from 0.00944 to 0.00943, saving model to model\best_model.hdf5
# 21/21 [==============================] - 0s 13ms/step - loss: 0.0127 - mse: 0.0083 - mae: 0.0647 - val_loss: 0.0094 - val_mse: 0.0050 - val_mae: 0.0551 - lr: 1.2207e-07
# Epoch 127/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0127 - mse: 0.0083 - mae: 0.0650
# Epoch 127: val_loss did not improve from 0.00943
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0128 - mse: 0.0083 - mae: 0.0651 - val_loss: 0.0094 - val_mse: 0.0050 - val_mae: 0.0551 - lr: 1.2207e-07
# Epoch 128/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0127 - mse: 0.0083 - mae: 0.0643
# Epoch 128: val_loss improved from 0.00943 to 0.00943, saving model to model\best_model.hdf5
#
# Epoch 128: ReduceLROnPlateau reducing learning rate to 1e-07.
# 21/21 [==============================] - 0s 12ms/step - loss: 0.0127 - mse: 0.0083 - mae: 0.0644 - val_loss: 0.0094 - val_mse: 0.0050 - val_mae: 0.0550 - lr: 1.2207e-07
# Epoch 129/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0127 - mse: 0.0083 - mae: 0.0645
# Epoch 129: val_loss improved from 0.00943 to 0.00942, saving model to model\best_model.hdf5
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0127 - mse: 0.0083 - mae: 0.0646 - val_loss: 0.0094 - val_mse: 0.0050 - val_mae: 0.0549 - lr: 1.0000e-07
# Epoch 130/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0125 - mse: 0.0080 - mae: 0.0641
# Epoch 130: val_loss improved from 0.00942 to 0.00941, saving model to model\best_model.hdf5
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0125 - mse: 0.0081 - mae: 0.0641 - val_loss: 0.0094 - val_mse: 0.0050 - val_mae: 0.0548 - lr: 1.0000e-07
# Epoch 131/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0128 - mse: 0.0083 - mae: 0.0645
# Epoch 131: val_loss did not improve from 0.00941
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0128 - mse: 0.0084 - mae: 0.0647 - val_loss: 0.0094 - val_mse: 0.0050 - val_mae: 0.0549 - lr: 1.0000e-07
# Epoch 132/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0132 - mse: 0.0087 - mae: 0.0661
# Epoch 132: val_loss did not improve from 0.00941
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0133 - mse: 0.0088 - mae: 0.0664 - val_loss: 0.0094 - val_mse: 0.0050 - val_mae: 0.0551 - lr: 1.0000e-07
# Epoch 133/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0122 - mse: 0.0078 - mae: 0.0631
# Epoch 133: val_loss did not improve from 0.00941
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0123 - mse: 0.0079 - mae: 0.0635 - val_loss: 0.0094 - val_mse: 0.0050 - val_mae: 0.0552 - lr: 1.0000e-07
# Epoch 134/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0127 - mse: 0.0083 - mae: 0.0649
# Epoch 134: val_loss did not improve from 0.00941
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0129 - mse: 0.0084 - mae: 0.0653 - val_loss: 0.0095 - val_mse: 0.0051 - val_mae: 0.0554 - lr: 1.0000e-07
# Epoch 135/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0127 - mse: 0.0083 - mae: 0.0642
# Epoch 135: val_loss did not improve from 0.00941
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0126 - mse: 0.0081 - mae: 0.0639 - val_loss: 0.0095 - val_mse: 0.0051 - val_mae: 0.0554 - lr: 1.0000e-07
# Epoch 136/500
# 17/21 [=======================>......] - ETA: 0s - loss: 0.0131 - mse: 0.0087 - mae: 0.0651
# Epoch 136: val_loss did not improve from 0.00941
# 21/21 [==============================] - 0s 12ms/step - loss: 0.0128 - mse: 0.0084 - mae: 0.0649 - val_loss: 0.0095 - val_mse: 0.0051 - val_mae: 0.0555 - lr: 1.0000e-07
# Epoch 137/500
# 21/21 [==============================] - ETA: 0s - loss: 0.0128 - mse: 0.0084 - mae: 0.0653
# Epoch 137: val_loss did not improve from 0.00941
# 21/21 [==============================] - 0s 12ms/step - loss: 0.0128 - mse: 0.0084 - mae: 0.0653 - val_loss: 0.0095 - val_mse: 0.0051 - val_mae: 0.0554 - lr: 1.0000e-07
# Epoch 138/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0129 - mse: 0.0085 - mae: 0.0653
# Epoch 138: val_loss did not improve from 0.00941
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0129 - mse: 0.0085 - mae: 0.0653 - val_loss: 0.0094 - val_mse: 0.0050 - val_mae: 0.0552 - lr: 1.0000e-07
# Epoch 139/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0125 - mse: 0.0081 - mae: 0.0643
# Epoch 139: val_loss did not improve from 0.00941
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0124 - mse: 0.0080 - mae: 0.0639 - val_loss: 0.0095 - val_mse: 0.0050 - val_mae: 0.0552 - lr: 1.0000e-07
# Epoch 140/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0128 - mse: 0.0084 - mae: 0.0649
# Epoch 140: val_loss did not improve from 0.00941
# Restoring model weights from the end of the best epoch: 130.
# 21/21 [==============================] - 0s 12ms/step - loss: 0.0128 - mse: 0.0084 - mae: 0.0650 - val_loss: 0.0095 - val_mse: 0.0051 - val_mae: 0.0554 - lr: 1.0000e-07
# Epoch 140: early stopping

# %%
save_lr_curve(H, f_name="DC_Power_LSTM")
# Out:
# Plot saved to .\預測結果圖\Plant1第一號發電機組\DC_Power_LSTM Learning Curve.png

# %%
# from tensorflow.keras.models import load_model

# # Load the best saved model
# model1 = load_model('model1/best_model.keras')
# model1.summary()

# %% [markdown]
# <h3> 評估模型 </h3>

# %% [markdown]
# <h4> TRAIN DATASET </h4>
# 對訓練數據進行預測

# %%
# Make predictions on the training data
train_predictions = model.predict(X_train).flatten() # 轉成一維陣列 → 方便後續比較與畫圖

# 比較預測值與實際值
train_results = pd.DataFrame({
    'Train Predictions': train_predictions, # 模型預測值
    'Actual Values': y_train.flatten() # 實際值
})

train_results
# Out:
# 82/82 [==============================] - 1s 4ms/step
#       Train Predictions  Actual Values
# 0              0.019336            0.0
# 1              0.020288            0.0
# 2              0.021430            0.0
# 3              0.022804            0.0
# 4              0.024396            0.0
# ...                 ...            ...
# 2595           0.023856            0.0
# 2596           0.025433            0.0
# 2597           0.027276            0.0
# 2598           0.029409            0.0
# 2599           0.031866            0.0
#
# [2600 rows x 2 columns]

# %%
save_prediction_plot(train_results['Actual Values'], train_results['Train Predictions'], mode='TRAIN') # 繪製y_test與y_test_pred的對比圖，展示預測值與實際值的偏差 (折線圖)
# Out:
# Plot saved to .\預測結果圖\Plant1第一號發電機組\TRAIN prediction.png

# %% [markdown]
# 兩條線大致重合，模型表現良好

# %% [markdown]
# <h4> VALIDATION DATA </h4>
# 對驗證集進行預測

# %%
val_predictions = model.predict(X_val).flatten()

# Create a DataFrame to compare predictions and actual values
val_results = pd.DataFrame({
    'Val Predictions': val_predictions,
    'Actual Values': y_val.flatten()  
})

val_results
# Out:
# 10/10 [==============================] - 0s 4ms/step
#      Val Predictions  Actual Values
# 0           0.034660       0.000000
# 1           0.037822       0.000000
# 2           0.041399       0.000000
# 3           0.045494       0.000000
# 4           0.050156       0.000000
# ..               ...            ...
# 295         0.066903       0.000000
# 296         0.074109       0.000000
# 297         0.082145       0.000000
# 298         0.090981       0.000000
# 299         0.100705       0.003566
#
# [300 rows x 2 columns]

# %%
save_prediction_plot(val_results['Actual Values'], val_results['Val Predictions'], mode='VALIDATION') # 繪製y_test與y_test_pred的對比圖，展示預測值與實際值的偏差 (折線圖)
# Out:
# Plot saved to .\預測結果圖\Plant1第一號發電機組\VALIDATION prediction.png

# %% [markdown]
# 兩條線高度重合，模型表現良好

# %% [markdown]
# <h4> testing data </h4>
# 對測試集進行預測

# %%
# Make predictions on the test data
test_predictions = model.predict(X_test).flatten()

# Create a DataFrame to compare predictions and actual values
test_results = pd.DataFrame({
    'Test Predictions': test_predictions,
    'Actual Values': y_test.flatten()  # Ensure y_test is flattened for consistency
})

# Display the first few rows of the DataFrame
test_results
# Out:
# 12/12 [==============================] - 0s 4ms/step
#      Test Predictions  Actual Values
# 0            0.111499       0.023603
# 1            0.123924       0.048885
# 2            0.138777       0.079535
# 3            0.156923       0.144732
# 4            0.180982       0.235570
# ..                ...            ...
# 354          0.018087       0.000000
# 355          0.017802       0.000000
# 356          0.017643       0.000000
# 357          0.017567       0.000000
# 358          0.017602       0.000000
#
# [359 rows x 2 columns]

# %%
save_prediction_plot(test_results['Actual Values'], test_results['Test Predictions'], mode='TESTING') # 繪製y_test與y_test_pred的對比圖，展示預測值與實際值的偏差 (折線圖)
# Out:
# Plot saved to .\預測結果圖\Plant1第一號發電機組\TESTING prediction.png

# %% [markdown]
# <h4> 評估模型在測試數據集上的表現 </h4>

# %%
metric_score(y_test.flatten(), test_predictions, model=model)
# Out:
# Mean Squared Error (MSE): 0.0088
# Root Mean Squared Error (RMSE): 0.0940
# Mean Absolute Error (MAE): 0.0652
# R² Score: 0.8757
# (<tf.Tensor: shape=(), dtype=float32, numpy=0.008841512>,
#  0.094029315,
#  <tf.Tensor: shape=(), dtype=float32, numpy=0.06523873>,
#  0.8756708755693569)

# %%
ErrorHistogram(y_test.flatten(), test_predictions)
# Out:
# Plot saved to .\預測結果圖\Plant1第一號發電機組\Error Histogram.png

# %%
save_yy_plot(y_test.flatten(), test_predictions)
# Out:
# Plot saved to .\預測結果圖\Plant1第一號發電機組\yy_plot.png

# %% [markdown]
# <!-- <p> 第二號發電機組發電量與天氣資訊 </p> -->
